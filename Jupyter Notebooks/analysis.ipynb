# %% [markdown]
# HCI-PROJECT, BUDAU ALEXANDRU
#
#
#
# This project analyzes anime-related data to explore trends, popularity, and geographic distribution of anime audiences. The analysis is developed in Jupyter Notebooks, which provide an interactive environment for combining code, visualizations, and explanations. Python is used as the main programming language together with data analysis libraries such as Pandas for data manipulation and Seaborn for statistical visualization. Geographic insights are generated using GeoSeaborn and Folium to create spatial and interactive maps. The goal of the project is to transform raw anime data into clear and meaningful visual insights.

# %% [markdown]
# Here we start by taking multiple files and start cleaning them

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("=" * 60)
print("1. LOADING ALTERNATE NAMES DATA")
print("=" * 60)

df_raw = pd.read_csv('datasets/person_alternate_names.csv')

print(f"Shape: {df_raw.shape}")
print(f"Rows: {df_raw.shape[0]:,} | Columns: {df_raw.shape[1]}")
print()
print(df_raw.head(10))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("=" * 60)
print("1. LOADING CHARACTERS DATA")
print("=" * 60)

df_raw = pd.read_csv('datasets/characters.csv')

print(f"Shape: {df_raw.shape}")
print(f"Rows: {df_raw.shape[0]:,} | Columns: {df_raw.shape[1]}")
print()
print(df_raw.head(10))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("=" * 60)
print("1. LOADING DETAILS DATA")
print("=" * 60)

df_raw = pd.read_csv('datasets/details.csv')

print(f"Shape: {df_raw.shape}")
print(f"Rows: {df_raw.shape[0]:,} | Columns: {df_raw.shape[1]}")
print()
print(df_raw.head(10))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("=" * 60)
print("1. LOADING PROFILES DATA")
print("=" * 60)

df_raw = pd.read_csv('datasets/profiles.csv')

print(f"Shape: {df_raw.shape}")
print(f"Rows: {df_raw.shape[0]:,} | Columns: {df_raw.shape[1]}")
print()
print(df_raw.head(10))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("=" * 60)
print("1. LOADING RECOMMENDATIONS DATA")
print("=" * 60)

df_raw = pd.read_csv('datasets/recommendations.csv')

print(f"Shape: {df_raw.shape}")
print(f"Rows: {df_raw.shape[0]:,} | Columns: {df_raw.shape[1]}")
print()
print(df_raw.head(10))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("=" * 60)
print("1. LOADING STATS DATA")
print("=" * 60)

df_raw = pd.read_csv('datasets/stats.csv')

print(f"Shape: {df_raw.shape}")
print(f"Rows: {df_raw.shape[0]:,} | Columns: {df_raw.shape[1]}")
print()
print(df_raw.head(10))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("=" * 60)
print("1. LOADING PERSON VOICE WORKS DATA")
print("=" * 60)

df_raw = pd.read_csv('datasets/person_voice_works.csv')

print(f"Shape: {df_raw.shape}")
print(f"Rows: {df_raw.shape[0]:,} | Columns: {df_raw.shape[1]}")
print()
print(df_raw.head(10))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("=" * 60)
print("1. LOADING PERSON DETAILS DATA")
print("=" * 60)

df_raw = pd.read_csv('datasets/person_details.csv')

print(f"Shape: {df_raw.shape}")
print(f"Rows: {df_raw.shape[0]:,} | Columns: {df_raw.shape[1]}")
print()
print(df_raw.head(10))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("=" * 60)
print("1. LOADING PERSON ANIME WORKS DATA")
print("=" * 60)

df_raw = pd.read_csv('datasets/person_anime_works.csv')

print(f"Shape: {df_raw.shape}")
print(f"Rows: {df_raw.shape[0]:,} | Columns: {df_raw.shape[1]}")
print()
print(df_raw.head(10))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("=" * 60)
print("1. LOADING FAVS DATA")
print("=" * 60)

df_raw = pd.read_csv('datasets/favs.csv')

print(f"Shape: {df_raw.shape}")
print(f"Rows: {df_raw.shape[0]:,} | Columns: {df_raw.shape[1]}")
print()
print(df_raw.head(10))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("=" * 60)
print("1. LOADING CHARACTER NICKNAMES DATA")
print("=" * 60)

df_raw = pd.read_csv('datasets/character_nicknames.csv')

print(f"Shape: {df_raw.shape}")
print(f"Rows: {df_raw.shape[0]:,} | Columns: {df_raw.shape[1]}")
print()
print(df_raw.head(10))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("=" * 60)
print("1. LOADING CHARACTER ANIME WORKS DATA")
print("=" * 60)

df_raw = pd.read_csv('datasets/character_anime_works.csv')

print(f"Shape: {df_raw.shape}")
print(f"Rows: {df_raw.shape[0]:,} | Columns: {df_raw.shape[1]}")
print()
print(df_raw.head(10))

# %% [markdown]
# I DECIDED TO SHOW JUST THE TOP 50 VALUES OF THE RATINGS.CSV AS THE FILE IS TOO LARGE TO BE HANDLED MOMENTARILY, AFTER WE CLEAN ALL THE USELESS DATA WE MIGHT BE ABLE TO WORK WITH THEM PROPERLY.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("=" * 60)
print("1. LOADING RATINGS DATA")
print("=" * 60)

df_raw = pd.read_csv('datasets/ratings.csv', nrows=50)

print(f"Shape: {df_raw.shape}")
print(f"Rows: {df_raw.shape[0]:,} | Columns: {df_raw.shape[1]}")
print()
print(df_raw.head(10))
