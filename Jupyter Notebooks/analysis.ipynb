# %% [markdown]
# ## HCI-PROJECT, BUDAU ALEXANDRU
#
# **This project analyzes anime-related data to explore trends, popularity, and geographic distribution of anime audiences. The analysis is developed in Jupyter Notebooks, which provide an interactive environment for combining code, visualizations, and explanations. Python is used as the main programming language together with data analysis libraries such as Pandas for data manipulation and Seaborn for statistical visualization. Geographic insights are generated using GeoSeaborn and Folium to create spatial and interactive maps. The goal of the project is to transform raw anime data into clear and meaningful visual insights.**

# %% [markdown]
# Here we start by taking multiple files and start cleaning them

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("=" * 60)
print("1. LOADING ALTERNATE NAMES DATA")
print("=" * 60)

df_raw = pd.read_csv('/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/person_alternate_names.csv')

print(f"Shape: {df_raw.shape}")
print(f"Rows: {df_raw.shape[0]:,} | Columns: {df_raw.shape[1]}")
print()
print(df_raw.head(10))
# Out:
# ...
# 1. LOADING ALTERNATE NAMES DATA
# ...
# Shape: (20465, 2)
# Rows: 20,465 | Columns: 2
#
#    person_mal_id         alt_name
# 0              1     Seki Mondoya
# 1              1             門戸 開
# 2              1     Monto Hiraku
# 3              3             雪野五月
# 4             10    Kevin Hatcher
# 5             11  Koichi Yamadera
# 6             12      David Lucas
# 7             12   Daniel Andrews
# 8             12    Andrew Watton
# 9             12   Brandon Jeremy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("=" * 60)
print("1. LOADING CHARACTERS DATA")
print("=" * 60)

df_raw = pd.read_csv('/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/characters.csv')

print(f"Shape: {df_raw.shape}")
print(f"Rows: {df_raw.shape[0]:,} | Columns: {df_raw.shape[1]}")
print()
print(df_raw.head(10))
# Out:
# ...
# 1. LOADING CHARACTERS DATA
# ...
# Shape: (209963, 7)
# Rows: 209,963 | Columns: 7
#
#    character_mal_id                                                url  \
# 0          280386.0  https://myanimelist.net/character/280386/Envi_...
# 1          280354.0    https://myanimelist.net/character/280354/Eleven
# 2          280353.0      https://myanimelist.net/character/280353/Stud
# 3          280352.0     https://myanimelist.net/character/280352/Judge
# 4          280339.0  https://myanimelist.net/character/280339/Eiji_...
# 5          280338.0  https://myanimelist.net/character/280338/Kaoru...
# 6          280337.0  https://myanimelist.net/character/280337/Minor...
# 7          280336.0  https://myanimelist.net/character/280336/Rin_S...
# 8          280335.0  https://myanimelist.net/character/280335/Kousu...
# 9          280334.0  https://myanimelist.net/character/280334/Akemi...
#
#                  name       name_kanji  \
# 0  Envi Mel Champagne  エンヴィ・メル・シャンパーニュ
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("=" * 60)
print("1. LOADING DETAILS DATA")
print("=" * 60)

df_raw = pd.read_csv('/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/details.csv')

print(f"Shape: {df_raw.shape}")
print(f"Rows: {df_raw.shape[0]:,} | Columns: {df_raw.shape[1]}")
print()
print(df_raw.head(10))
# Out:
# ...
# 1. LOADING DETAILS DATA
# ...
# Shape: (28955, 29)
# Rows: 28,955 | Columns: 29
#
#    mal_id                                              title  \
# 0   59356                                           -Socket-
# 1   56036                                             ......
# 2    2928                               .hack//G.U. Returner
# 3    3269                                .hack//G.U. Trilogy
# 4    4469                   .hack//G.U. Trilogy: Parody Mode
# 5     454                                        .hack//Gift
# 6    1143                                  .hack//Intermezzo
# 7     299                                  .hack//Liminality
# 8    9332                                     .hack//Quantum
# 9   10390  .hack//Quantum: Sore ike! Bokura no Chimuchimu...
#
#                            title_japanese  \
# 0                                -socket-
# 1                                  ......
# 2                    .HACK//G.U. RETURNER
# 3                     .hack//G.U. Trilogy
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("=" * 60)
print("1. LOADING PROFILES DATA")
print("=" * 60)

df_raw = pd.read_csv('/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/profiles.csv')

print(f"Shape: {df_raw.shape}")
print(f"Rows: {df_raw.shape[0]:,} | Columns: {df_raw.shape[1]}")
print()
print(df_raw.head(10))
# Out:
# ...
# 1. LOADING PROFILES DATA
# ...
# Shape: (337155, 10)
# Rows: 337,155 | Columns: 10
#
#        username  gender birthday       location        joined watching  \
# 0     ishikawas     NaN      NaN    South Korea           NaN      NaN
# 1          CKK2     NaN      NaN  United States   Dec 1, 2018        3
# 2   --------788  Female      NaN         Mexico   Oct 4, 2022        1
# 3    potatoaris     NaN      NaN          Spain   Oct 2, 2018        5
# 4     Rinrintan     NaN      NaN          Japan  May 12, 2019       20
# 5    Karincakes     NaN      NaN         Turkey   Jan 5, 2015       79
# 6   Folktal3wtb     NaN      NaN    South Korea   Jan 3, 2021       40
# 7  Monarchivist     NaN      NaN      Indonesia  Nov 16, 2024        1
# 8      Thom_dos     NaN      NaN          Japan   Sep 2, 2021        7
# 9     arizkykun    Male      NaN  United States  Jan 16, 2016        3
#
#   completed on_hold dropped plan_to_watch
# 0       NaN     NaN     NaN           NaN
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("=" * 60)
print("1. LOADING RECOMMENDATIONS DATA")
print("=" * 60)

df_raw = pd.read_csv('/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/recommendations.csv')

print(f"Shape: {df_raw.shape}")
print(f"Rows: {df_raw.shape[0]:,} | Columns: {df_raw.shape[1]}")
print()
print(df_raw.head(10))
# Out:
# ...
# 1. LOADING RECOMMENDATIONS DATA
# ...
# Shape: (105249, 2)
# Rows: 105,249 | Columns: 2
#
#    mal_id  recommendation_mal_id
# 0    3269                    317
# 1    3269                   6922
# 2    3269                    299
# 3    3269                   3446
# 4    3269                   5681
# 5    3269                   6444
# 6    3269                   8311
# 7    4469                   5501
# 8     454                  10012
# 9     454                  31471

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("=" * 60)
print("1. LOADING STATS DATA")
print("=" * 60)

df_raw = pd.read_csv('/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/stats.csv')

print(f"Shape: {df_raw.shape}")
print(f"Rows: {df_raw.shape[0]:,} | Columns: {df_raw.shape[1]}")
print()
print(df_raw.head(10))
# Out:
# ...
# 1. LOADING STATS DATA
# ...
# Shape: (28955, 27)
# Rows: 28,955 | Columns: 27
#
#    mal_id  watching  completed  on_hold  dropped  plan_to_watch  total  \
# 0   59356         7        146        4       20             20    197
# 1   56036        21        770        8       29            113    941
# 2    2928       451      14953      302      349           6472  22527
# 3    3269       726      22790      452      537           9762  34267
# 4    4469       241       6918      182      266           3528  11135
# 5     454       325      15421      261      423           5027  21457
# 6    1143       360      17510      302      323           5847  24342
# 7     299       858      24478     1149      998           7504  34987
# 8    9332      1156      28997      635      683          10752  42223
# 9   10390       247       4643      166      293           3487   8836
#
#    score_1_votes  score_1_percentage  score_2_votes  ...  score_6_votes  \
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("=" * 60)
print("1. LOADING PERSON VOICE WORKS DATA")
print("=" * 60)

df_raw = pd.read_csv('/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/person_voice_works.csv')

print(f"Shape: {df_raw.shape}")
print(f"Rows: {df_raw.shape[0]:,} | Columns: {df_raw.shape[1]}")
print()
print(df_raw.head(10))
# Out:
# ...
# 1. LOADING PERSON VOICE WORKS DATA
# ...
# Shape: (489516, 5)
# Rows: 489,516 | Columns: 5
#
#    person_mal_id        role  anime_mal_id  character_mal_id  language
# 0              1        Main         55830              2514  Japanese
# 1              1  Supporting         60602              2822  Japanese
# 2              1  Supporting         59229            140499  Japanese
# 3              1  Supporting         60427            275856  Japanese
# 4              1  Supporting         62067            190335  Japanese
# 5              1  Supporting         60564            256949  Japanese
# 6              1  Supporting         58772            163197  Japanese
# 7              1  Supporting         62149              2514  Japanese
# 8              1  Supporting         59192            151149  Japanese
# 9              1        Main         53722            268279  Japanese

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("=" * 60)
print("1. LOADING PERSON DETAILS DATA")
print("=" * 60)

df_raw = pd.read_csv('/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/person_details.csv')

print(f"Shape: {df_raw.shape}")
print(f"Rows: {df_raw.shape[0]:,} | Columns: {df_raw.shape[1]}")
print()
print(df_raw.head(10))
# Out:
# ...
# 1. LOADING PERSON DETAILS DATA
# ...
# Shape: (76699, 10)
# Rows: 76,699 | Columns: 10
#
#    person_mal_id                                                url  \
# 0              1     https://myanimelist.net/people/1/Tomokazu_Seki
# 1              2   https://myanimelist.net/people/2/Tomokazu_Sugita
# 2              3    https://myanimelist.net/people/3/Satsuki_Yukino
# 3              4        https://myanimelist.net/people/4/Aya_Hirano
# 4              5  https://myanimelist.net/people/5/Kenichi_Suzumura
# 5              6  https://myanimelist.net/people/6/Toshiyuki_Mor...
# 6              7   https://myanimelist.net/people/7/Eiji_Yanagisawa
# 7              8      https://myanimelist.net/people/8/Rie_Kugimiya
# 8              9  https://myanimelist.net/people/9/Kotono_Mitsuishi
# 9             10  https://myanimelist.net/people/10/Johnny_Yong_...
#
#                                          website_url  \
# 0                                                NaN
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("=" * 60)
print("1. LOADING PERSON ANIME WORKS DATA")
print("=" * 60)

df_raw = pd.read_csv('/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/person_anime_works.csv')

print(f"Shape: {df_raw.shape}")
print(f"Rows: {df_raw.shape[0]:,} | Columns: {df_raw.shape[1]}")
print()
print(df_raw.head(10))
# Out:
# ...
# 1. LOADING PERSON ANIME WORKS DATA
# ...
# Shape: (458091, 3)
# Rows: 458,091 | Columns: 3
#
#    person_mal_id                          position  anime_mal_id
# 0              1            Theme Song Performance          3080
# 1              1         Inserted Song Performance         15699
# 2              1       Theme Song Performance (OP)           247
# 3              1            Theme Song Performance           258
# 4              1       Theme Song Performance (ED)         34825
# 5              1  Theme Song Performance (Opening)          1628
# 6              1            Theme Song Performance          4560
# 7              1       Theme Song Performance (ED)         30016
# 8              1       Theme Song Performance (ED)         34414
# 9              1            Theme Song Performance          1027

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("=" * 60)
print("1. LOADING FAVS DATA")
print("=" * 60)

df_raw = pd.read_csv('/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/favs.csv')

print(f"Shape: {df_raw.shape}")
print(f"Rows: {df_raw.shape[0]:,} | Columns: {df_raw.shape[1]}")
print()
print(df_raw.head(10))
# Out:
# ...
# 1. LOADING FAVS DATA
# ...
# Shape: (4178747, 3)
# Rows: 4,178,747 | Columns: 3
#
#     username   fav_type      id
# 0  ishikawas      anime   45649
# 1  ishikawas      anime   38680
# 2  ishikawas      anime     795
# 3  ishikawas      anime   37510
# 4  ishikawas      anime     820
# 5  ishikawas      anime   31933
# 6  ishikawas      anime   35857
# 7  ishikawas      anime   11061
# 8  ishikawas      anime    2001
# 9  ishikawas  character  172491

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("=" * 60)
print("1. LOADING CHARACTER NICKNAMES DATA")
print("=" * 60)

df_raw = pd.read_csv('/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/character_nicknames.csv')

print(f"Shape: {df_raw.shape}")
print(f"Rows: {df_raw.shape[0]:,} | Columns: {df_raw.shape[1]}")
print()
print(df_raw.head(10))
# Out:
# ...
# 1. LOADING CHARACTER NICKNAMES DATA
# ...
# Shape: (37080, 2)
# Rows: 37,080 | Columns: 2
#
#    character_mal_id                        nickname
# 0            280205                        Hikaruko
# 1            280129                        Hinacchi
# 2            280127                   Bertha Willis
# 3            280066                           Jimmy
# 4            280059            Full Body Red Square
# 5            280058           Master of the Skywalk
# 6            280054                    Last Pharaoh
# 7            280052  Heaven Shattering Sword Master
# 8            280048                         War God
# 9            280043                     Bartholomew

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("=" * 60)
print("1. LOADING CHARACTER ANIME WORKS DATA")
print("=" * 60)

df_raw = pd.read_csv('/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/character_anime_works.csv')

print(f"Shape: {df_raw.shape}")
print(f"Rows: {df_raw.shape[0]:,} | Columns: {df_raw.shape[1]}")
print()
print(df_raw.head(10))
# Out:
# ...
# 1. LOADING CHARACTER ANIME WORKS DATA
# ...
# Shape: (236816, 4)
# Rows: 236,816 | Columns: 4
#
#    anime_mal_id  character_mal_id character_name        role
# 0          2928              5781          Atoli        Main
# 1          2928                33          Haseo        Main
# 2          2928                32           Ovan        Main
# 3          2928                34          Shino        Main
# 4          2928              5785           Aina  Supporting
# 5          2928              5784       Endrance  Supporting
# 6          2928             28978        Gaspard  Supporting
# 7          2928             29012            Ita  Supporting
# 8          2928              5782           Kuhn  Supporting
# 9          2928             31573          Matsu  Supporting

# %% [markdown]
# I DECIDED TO SHOW JUST THE TOP 50 VALUES OF THE RATINGS.CSV AS THE FILE IS TOO LARGE TO BE HANDLED MOMENTARILY, AFTER WE CLEAN ALL THE USELESS DATA WE MIGHT BE ABLE TO WORK WITH THEM PROPERLY.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("=" * 60)
print("1. LOADING RATINGS DATA")
print("=" * 60)

df_raw = pd.read_csv('/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/ratings.csv', nrows=50)

print(f"Shape: {df_raw.shape}")
print(f"Rows: {df_raw.shape[0]:,} | Columns: {df_raw.shape[1]}")
print()
print(df_raw.head(10))
# Out:
# ...
# 1. LOADING RATINGS DATA
# ...
# Shape: (50, 6)
# Rows: 50 | Columns: 6
#
#       username  anime_id     status  score  is_rewatching  \
# 0  --------788     30276   watching      7            0.0
# 1  --------788     28851  completed      7            0.0
# 2  --------788     41168  completed      7            0.0
# 3  --------788     22199  completed     10            0.0
# 4  --------788     16498  completed     10            0.0
# 5  --------788     25777  completed     10            0.0
# 6  --------788     35760  completed     10            0.0
# 7  --------788     38524  completed     10            0.0
# 8  --------788     40028  completed      8            0.0
# 9  --------788     51535  completed     10            0.0
#
#    num_watched_episodes
# 0                     3
# 1                     1
# 2                     1
# 3                    24
# 4                    25
# 5                    12
# 6                    12
# 7                    10
# 8                    16
# ...

# %% [markdown]
# NOW WE GET TO THE CLEANING PART, LET'S SEE WHAT THESE FILES HAVE GOT FOR US

# %%
import pandas as pd

BASE_PATH = '/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/'

FILES = {
    'person_alternate_names' : BASE_PATH + 'person_alternate_names.csv',
    'characters'             : BASE_PATH + 'characters.csv',
    'details'                : BASE_PATH + 'details.csv',
    'profiles'               : BASE_PATH + 'profiles.csv',
    'recommendations'        : BASE_PATH + 'recommendations.csv',
    'stats'                  : BASE_PATH + 'stats.csv',
    'person_voice_works'     : BASE_PATH + 'person_voice_works.csv',
    'person_details'         : BASE_PATH + 'person_details.csv',
    'person_anime_works'     : BASE_PATH + 'person_anime_works.csv',
    'favs'                   : BASE_PATH + 'favs.csv',
    'character_nicknames'    : BASE_PATH + 'character_nicknames.csv',
    'character_anime_works'  : BASE_PATH + 'character_anime_works.csv',
    'ratings'                : BASE_PATH + 'ratings.csv',
}
print('Succesful')
# Out:
# Succesful

# %% [markdown]
#     These functions will print the number of NaN values per column and the total.
#     They will return a DataFrame with the results.

# %%
df = pd.read_csv('/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/person_alternate_names.csv')

# NaN Report
nan_per_col = df.isnull().sum()
nan_pct     = (df.isnull().mean() * 100).round(2)
total_nan   = nan_per_col.sum()
total_cells = df.shape[0] * df.shape[1]

result = pd.DataFrame({
    'column'    : nan_per_col.index,
    'nan_count' : nan_per_col.values,
    'nan_%'     : nan_pct.values
})
result = result[result['nan_count'] > 0].reset_index(drop=True)

print(f"\n{'─'*50}")
print(f"  NaN REPORT — person_alternate_names")
print(f"{'─'*50}")
if result.empty:
    print("  No NaN values found.")
else:
    print(result.to_string(index=False))
print(f"\n  Total NaN     : {total_nan:,}")
print(f"  Total cells   : {total_cells:,}")
print(f"  NaN overall % : {(total_nan / total_cells * 100):.2f}%")
# Out:
# ──────────────────────────────────────────────────
#   NaN REPORT — person_alternate_names
# ──────────────────────────────────────────────────
#   column  nan_count  nan_%
# alt_name         18   0.09
#
#   Total NaN     : 18
#   Total cells   : 40,930
#   NaN overall % : 0.04%

# %%
df = pd.read_csv('/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/characters.csv')

# NaN Report
nan_per_col = df.isnull().sum()
nan_pct     = (df.isnull().mean() * 100).round(2)
total_nan   = nan_per_col.sum()
total_cells = df.shape[0] * df.shape[1]

result = pd.DataFrame({
    'column'    : nan_per_col.index,
    'nan_count' : nan_per_col.values,
    'nan_%'     : nan_pct.values
})
result = result[result['nan_count'] > 0].reset_index(drop=True)

print(f"\n{'─'*50}")
print(f"  NaN REPORT — characters")
print(f"{'─'*50}")
if result.empty:
    print("  No NaN values found.")
else:
    print(result.to_string(index=False))
print(f"\n  Total NaN     : {total_nan:,}")
print(f"  Total cells   : {total_cells:,}")
print(f"  NaN overall % : {(total_nan / total_cells * 100):.2f}%")
# Out:
# ──────────────────────────────────────────────────
#   NaN REPORT — characters
# ──────────────────────────────────────────────────
#           column  nan_count  nan_%
# character_mal_id          2   0.00
#              url          2   0.00
#             name          2   0.00
#       name_kanji      55480  26.42
#            image          2   0.00
#        favorites          2   0.00
#            about      96976  46.19
#
#   Total NaN     : 152,466
#   Total cells   : 1,469,741
#   NaN overall % : 10.37%

# %%
df = pd.read_csv('/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/character_anime_works.csv')

# NaN Report
nan_per_col = df.isnull().sum()
nan_pct     = (df.isnull().mean() * 100).round(2)
total_nan   = nan_per_col.sum()
total_cells = df.shape[0] * df.shape[1]

result = pd.DataFrame({
    'column'    : nan_per_col.index,
    'nan_count' : nan_per_col.values,
    'nan_%'     : nan_pct.values
})
result = result[result['nan_count'] > 0].reset_index(drop=True)

print(f"\n{'─'*50}")
print(f"  NaN REPORT — character_anime_works")
print(f"{'─'*50}")
if result.empty:
    print("  No NaN values found.")
else:
    print(result.to_string(index=False))
print(f"\n  Total NaN     : {total_nan:,}")
print(f"  Total cells   : {total_cells:,}")
print(f"  NaN overall % : {(total_nan / total_cells * 100):.2f}%")
# Out:
# ──────────────────────────────────────────────────
#   NaN REPORT — character_anime_works
# ──────────────────────────────────────────────────
#   No NaN values found.
#
#   Total NaN     : 0
#   Total cells   : 947,264
#   NaN overall % : 0.00%

# %% [markdown]
# As we can see, the file "character_anime_works.csv" was clean and the search produced a 0.0% of NaN overall.

# %%
df = pd.read_csv('/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/character_nicknames.csv')

# NaN Report
nan_per_col = df.isnull().sum()
nan_pct     = (df.isnull().mean() * 100).round(2)
total_nan   = nan_per_col.sum()
total_cells = df.shape[0] * df.shape[1]

result = pd.DataFrame({
    'column'    : nan_per_col.index,
    'nan_count' : nan_per_col.values,
    'nan_%'     : nan_pct.values
})
result = result[result['nan_count'] > 0].reset_index(drop=True)

print(f"\n{'─'*50}")
print(f"  NaN REPORT — character_nicknames")
print(f"{'─'*50}")
if result.empty:
    print("  No NaN values found.")
else:
    print(result.to_string(index=False))
print(f"\n  Total NaN     : {total_nan:,}")
print(f"  Total cells   : {total_cells:,}")
print(f"  NaN overall % : {(total_nan / total_cells * 100):.2f}%")
# Out:
# ──────────────────────────────────────────────────
#   NaN REPORT — character_nicknames
# ──────────────────────────────────────────────────
#   column  nan_count  nan_%
# nickname         16   0.04
#
#   Total NaN     : 16
#   Total cells   : 74,160
#   NaN overall % : 0.02%

# %%
df = pd.read_csv('/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/details.csv')

# NaN Report
nan_per_col = df.isnull().sum()
nan_pct     = (df.isnull().mean() * 100).round(2)
total_nan   = nan_per_col.sum()
total_cells = df.shape[0] * df.shape[1]

result = pd.DataFrame({
    'column'    : nan_per_col.index,
    'nan_count' : nan_per_col.values,
    'nan_%'     : nan_pct.values
})
result = result[result['nan_count'] > 0].reset_index(drop=True)

print(f"\n{'─'*50}")
print(f"  NaN REPORT — details")
print(f"{'─'*50}")
if result.empty:
    print("  No NaN values found.")
else:
    print(result.to_string(index=False))
print(f"\n  Total NaN     : {total_nan:,}")
print(f"  Total cells   : {total_cells:,}")
print(f"  NaN overall % : {(total_nan / total_cells * 100):.2f}%")
# Out:
# ──────────────────────────────────────────────────
#   NaN REPORT — details
# ──────────────────────────────────────────────────
#         column  nan_count  nan_%
# title_japanese        119   0.41
#           type         67   0.23
#          score      10073  34.79
#      scored_by      10073  34.79
#     start_date        851   2.94
#       end_date      17688  61.09
#       synopsis       5127  17.71
#           rank       6958  24.03
#         rating        600   2.07
#       episodes        680   2.35
#         season      22689  78.36
#           year      22689  78.36
#
#   Total NaN     : 97,614
#   Total cells   : 839,695
#   NaN overall % : 11.62%

# %%
df = pd.read_csv('/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/favs.csv')

# NaN Report
nan_per_col = df.isnull().sum()
nan_pct     = (df.isnull().mean() * 100).round(2)
total_nan   = nan_per_col.sum()
total_cells = df.shape[0] * df.shape[1]

result = pd.DataFrame({
    'column'    : nan_per_col.index,
    'nan_count' : nan_per_col.values,
    'nan_%'     : nan_pct.values
})
result = result[result['nan_count'] > 0].reset_index(drop=True)

print(f"\n{'─'*50}")
print(f"  NaN REPORT — favs")
print(f"{'─'*50}")
if result.empty:
    print("  No NaN values found.")
else:
    print(result.to_string(index=False))
print(f"\n  Total NaN     : {total_nan:,}")
print(f"  Total cells   : {total_cells:,}")
print(f"  NaN overall % : {(total_nan / total_cells * 100):.2f}%")
# Out:
# ──────────────────────────────────────────────────
#   NaN REPORT — favs
# ──────────────────────────────────────────────────
#   column  nan_count  nan_%
# username          4    0.0
#
#   Total NaN     : 4
#   Total cells   : 12,536,241
#   NaN overall % : 0.00%

# %%
df = pd.read_csv('/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/person_details.csv')

# NaN Report
nan_per_col = df.isnull().sum()
nan_pct     = (df.isnull().mean() * 100).round(2)
total_nan   = nan_per_col.sum()
total_cells = df.shape[0] * df.shape[1]

result = pd.DataFrame({
    'column'    : nan_per_col.index,
    'nan_count' : nan_per_col.values,
    'nan_%'     : nan_pct.values
})
result = result[result['nan_count'] > 0].reset_index(drop=True)

print(f"\n{'─'*50}")
print(f"  NaN REPORT — person_details")
print(f"{'─'*50}")
if result.empty:
    print("  No NaN values found.")
else:
    print(result.to_string(index=False))
print(f"\n  Total NaN     : {total_nan:,}")
print(f"  Total cells   : {total_cells:,}")
print(f"  NaN overall % : {(total_nan / total_cells * 100):.2f}%")
# Out:
# ──────────────────────────────────────────────────
#   NaN REPORT — person_details
# ──────────────────────────────────────────────────
#      column  nan_count  nan_%
# website_url      59264  77.27
#        name          2   0.00
#  given_name      30253  39.44
# family_name      18641  24.30
#    birthday      59461  77.53
#
#   Total NaN     : 167,621
#   Total cells   : 766,990
#   NaN overall % : 21.85%

# %%
df = pd.read_csv('/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/person_voice_works.csv')

# NaN Report
nan_per_col = df.isnull().sum()
nan_pct     = (df.isnull().mean() * 100).round(2)
total_nan   = nan_per_col.sum()
total_cells = df.shape[0] * df.shape[1]

result = pd.DataFrame({
    'column'    : nan_per_col.index,
    'nan_count' : nan_per_col.values,
    'nan_%'     : nan_pct.values
})
result = result[result['nan_count'] > 0].reset_index(drop=True)

print(f"\n{'─'*50}")
print(f"  NaN REPORT — person_voice_works")
print(f"{'─'*50}")
if result.empty:
    print("  No NaN values found.")
else:
    print(result.to_string(index=False))
print(f"\n  Total NaN     : {total_nan:,}")
print(f"  Total cells   : {total_cells:,}")
print(f"  NaN overall % : {(total_nan / total_cells * 100):.2f}%")
# Out:
# ──────────────────────────────────────────────────
#   NaN REPORT — person_voice_works
# ──────────────────────────────────────────────────
#   No NaN values found.
#
#   Total NaN     : 0
#   Total cells   : 2,447,580
#   NaN overall % : 0.00%

# %%
df = pd.read_csv('/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/profiles.csv')

# NaN Report
nan_per_col = df.isnull().sum()
nan_pct     = (df.isnull().mean() * 100).round(2)
total_nan   = nan_per_col.sum()
total_cells = df.shape[0] * df.shape[1]

result = pd.DataFrame({
    'column'    : nan_per_col.index,
    'nan_count' : nan_per_col.values,
    'nan_%'     : nan_pct.values
})
result = result[result['nan_count'] > 0].reset_index(drop=True)

print(f"\n{'─'*50}")
print(f"  NaN REPORT — profiles")
print(f"{'─'*50}")
if result.empty:
    print("  No NaN values found.")
else:
    print(result.to_string(index=False))
print(f"\n  Total NaN     : {total_nan:,}")
print(f"  Total cells   : {total_cells:,}")
print(f"  NaN overall % : {(total_nan / total_cells * 100):.2f}%")
# Out:
# ──────────────────────────────────────────────────
#   NaN REPORT — profiles
# ──────────────────────────────────────────────────
#        column  nan_count  nan_%
#      username          1   0.00
#        gender     170876  50.68
#      birthday     215826  64.01
#        joined       1676   0.50
#      watching       1678   0.50
#     completed       1678   0.50
#       on_hold       1678   0.50
#       dropped       1678   0.50
# plan_to_watch       1678   0.50
#
#   Total NaN     : 396,769
#   Total cells   : 3,371,550
#   NaN overall % : 11.77%

# %%
df = pd.read_csv('/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/person_anime_works.csv')

# NaN Report
nan_per_col = df.isnull().sum()
nan_pct     = (df.isnull().mean() * 100).round(2)
total_nan   = nan_per_col.sum()
total_cells = df.shape[0] * df.shape[1]

result = pd.DataFrame({
    'column'    : nan_per_col.index,
    'nan_count' : nan_per_col.values,
    'nan_%'     : nan_pct.values
})
result = result[result['nan_count'] > 0].reset_index(drop=True)

print(f"\n{'─'*50}")
print(f"  NaN REPORT — person_anime_works")
print(f"{'─'*50}")
if result.empty:
    print("  No NaN values found.")
else:
    print(result.to_string(index=False))
print(f"\n  Total NaN     : {total_nan:,}")
print(f"  Total cells   : {total_cells:,}")
print(f"  NaN overall % : {(total_nan / total_cells * 100):.2f}%")
# Out:
# ──────────────────────────────────────────────────
#   NaN REPORT — person_anime_works
# ──────────────────────────────────────────────────
#   No NaN values found.
#
#   Total NaN     : 0
#   Total cells   : 1,374,273
#   NaN overall % : 0.00%

# %%
df = pd.read_csv('/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/recommendations.csv')

# NaN Report
nan_per_col = df.isnull().sum()
nan_pct     = (df.isnull().mean() * 100).round(2)
total_nan   = nan_per_col.sum()
total_cells = df.shape[0] * df.shape[1]

result = pd.DataFrame({
    'column'    : nan_per_col.index,
    'nan_count' : nan_per_col.values,
    'nan_%'     : nan_pct.values
})
result = result[result['nan_count'] > 0].reset_index(drop=True)

print(f"\n{'─'*50}")
print(f"  NaN REPORT — recommendations")
print(f"{'─'*50}")
if result.empty:
    print("  No NaN values found.")
else:
    print(result.to_string(index=False))
print(f"\n  Total NaN     : {total_nan:,}")
print(f"  Total cells   : {total_cells:,}")
print(f"  NaN overall % : {(total_nan / total_cells * 100):.2f}%")
# Out:
# ──────────────────────────────────────────────────
#   NaN REPORT — recommendations
# ──────────────────────────────────────────────────
#   No NaN values found.
#
#   Total NaN     : 0
#   Total cells   : 210,498
#   NaN overall % : 0.00%

# %%
df = pd.read_csv('/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/stats.csv')

# NaN Report
nan_per_col = df.isnull().sum()
nan_pct     = (df.isnull().mean() * 100).round(2)
total_nan   = nan_per_col.sum()
total_cells = df.shape[0] * df.shape[1]

result = pd.DataFrame({
    'column'    : nan_per_col.index,
    'nan_count' : nan_per_col.values,
    'nan_%'     : nan_pct.values
})
result = result[result['nan_count'] > 0].reset_index(drop=True)

print(f"\n{'─'*50}")
print(f"  NaN REPORT — stats")
print(f"{'─'*50}")
if result.empty:
    print("  No NaN values found.")
else:
    print(result.to_string(index=False))
print(f"\n  Total NaN     : {total_nan:,}")
print(f"  Total cells   : {total_cells:,}")
print(f"  NaN overall % : {(total_nan / total_cells * 100):.2f}%")
# Out:
# ──────────────────────────────────────────────────
#   NaN REPORT — stats
# ──────────────────────────────────────────────────
#              column  nan_count  nan_%
#       score_1_votes        430   1.49
#  score_1_percentage        430   1.49
#       score_2_votes        430   1.49
#  score_2_percentage        430   1.49
#       score_3_votes        430   1.49
#  score_3_percentage        430   1.49
#       score_4_votes        430   1.49
#  score_4_percentage        430   1.49
#       score_5_votes        430   1.49
#  score_5_percentage        430   1.49
#       score_6_votes        430   1.49
#  score_6_percentage        430   1.49
#       score_7_votes        430   1.49
#  score_7_percentage        430   1.49
#       score_8_votes        430   1.49
#  score_8_percentage        430   1.49
#       score_9_votes        430   1.49
#  score_9_percentage        430   1.49
#      score_10_votes        430   1.49
# score_10_percentage        430   1.49
#
#   Total NaN     : 8,600
# ...

# %% [markdown]
# NOW IT'S TIME TO CLEAN THIS ALL UP

# %% [markdown]
# Person Alter Name - Simple lookup table. We strip whitespace from names, drop nulls (a name with no value is useless), drop empty strings, and remove duplicates on the (person_mal_id, alt_name) pair since the same alias listed twice for the same person is redundant.

# %%
# =============================================================================
# ANIME DATASET — DATA CLEANING
# File: person_alternate_names.csv
# =============================================================================
import os

BASE_PATH = '/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/'
OUT_PATH  = '/Users/alexandrubudau/Desktop/HCI-PROJECT/cleaned datasets/'
os.makedirs(OUT_PATH, exist_ok=True)

print("=" * 60)
print("CLEANING: person_alternate_names.csv")
print("=" * 60)

df = pd.read_csv(BASE_PATH + 'person_alternate_names.csv')
raw = df.copy()

print(f"\nRaw shape: {df.shape}")
print(df.head(5))

# --- Strip whitespace ---
df['alt_name'] = df['alt_name'].str.strip()

# --- Drop nulls ---
df = df.dropna(subset=['alt_name'])

# --- Drop empty strings ---
df = df[df['alt_name'] != '']

# --- Drop duplicates ---
df = df.drop_duplicates(subset=['person_mal_id', 'alt_name'])

# --- Summary ---
print(f"\n{'─'*60}")
print(f"  Rows before : {len(raw):,}")
print(f"  Nulls removed       : {raw['alt_name'].isnull().sum()}")
print(f"  Duplicates removed  : {raw.duplicated(subset=['person_mal_id','alt_name']).sum()}")
print(f"  Rows after  : {len(df):,}")
print(f"{'─'*60}")

df.to_csv(OUT_PATH + 'person_alternate_names_clean.csv', index=False)
print("Saved → person_alternate_names_clean.csv")
# Out:
# ...
# CLEANING: person_alternate_names.csv
# ...
#
# Raw shape: (20465, 2)
#    person_mal_id       alt_name
# 0              1   Seki Mondoya
# 1              1           門戸 開
# 2              1   Monto Hiraku
# 3              3           雪野五月
# 4             10  Kevin Hatcher
#
# ────────────────────────────────────────────────────────────
#   Rows before : 20,465
#   Nulls removed       : 18
#   Duplicates removed  : 39
#   Rows after  : 20,408
# ────────────────────────────────────────────────────────────
# Saved → person_alternate_names_clean.csv

# %% [markdown]
# Characters — We drop the url column since links aren't useful for data analysis. name is critical so rows missing it are dropped. about and favorites are optional fields so instead of dropping we fill them with '' and 0 respectively. Dedup on character_mal_id since each character should appear once.

# %%
# =============================================================================
# ANIME DATASET — DATA CLEANING
# File: characters.csv
# =============================================================================

import pandas as pd
import os

BASE_PATH = '/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/'
OUT_PATH  = '/Users/alexandrubudau/Desktop/HCI-PROJECT/cleaned datasets/'

print("=" * 60)
print("CLEANING: characters.csv")
print("=" * 60)

df = pd.read_csv(BASE_PATH + 'characters.csv')
raw = df.copy()

print(f"\nRaw shape: {df.shape}")
print(df.head(5))

# --- Drop URL column (not useful for analysis) ---
df = df.drop(columns=['url'], errors='ignore')

# --- Drop rows with no name (critical field) ---
df = df.dropna(subset=['name'])

# --- Strip text fields ---
df['name']       = df['name'].str.strip()
df['name_kanji'] = df['name_kanji'].str.strip()

# --- Fill missing about with empty string ---
df['about'] = df['about'].fillna('')

# --- Fill missing favorites with 0 ---
df['favorites'] = df['favorites'].fillna(0).astype(int)

# --- Drop duplicates on ID ---
df = df.drop_duplicates(subset=['character_mal_id'])

# --- Summary ---
print(f"\n{'─'*60}")
print(f"  Rows before         : {len(raw):,}")
print(f"  Nulls (name)        : {raw['name'].isnull().sum()}")
print(f"  Duplicates removed  : {raw.duplicated(subset=['character_mal_id']).sum()}")
print(f"  Rows after          : {len(df):,}")
print(f"{'─'*60}")

df.to_csv(OUT_PATH + 'characters_clean.csv', index=False)
print("Saved → characters_clean.csv")
# Out:
# ...
# CLEANING: characters.csv
# ...
#
# Raw shape: (209963, 7)
#    character_mal_id                                                url  \
# 0          280386.0  https://myanimelist.net/character/280386/Envi_...
# 1          280354.0    https://myanimelist.net/character/280354/Eleven
# 2          280353.0      https://myanimelist.net/character/280353/Stud
# 3          280352.0     https://myanimelist.net/character/280352/Judge
# 4          280339.0  https://myanimelist.net/character/280339/Eiji_...
#
#                  name       name_kanji  \
# 0  Envi Mel Champagne  エンヴィ・メル・シャンパーニュ
# 1              Eleven             イレヴン
# 2                Stud             スタッド
# 3               Judge             ジャッジ
# 4       Eiji Kurokawa            黒川 英治
#
#                                                image  favorites about
# 0  https://cdn.myanimelist.net/images/characters/...        0.0   NaN
# 1  https://cdn.myanimelist.net/images/characters/...        0.0   NaN
# ...

# %% [markdown]
# **In this part of cleaning, a score of 0 or 0 episodes means something very different from "unknown". Keeping them as NaN means pandas and seaborn will simply skip them in calculations and plots, which is the correct behaviour.**

# %% [markdown]
# *Details — The richest file. We drop url and image_url, parse start_date and end_date into proper datetime objects and extract start_year and start_month for trend analysis. All numeric fields are coerced to numbers. Missing score and episodes are kept as NaN intentionally — they're optional and dropping them would lose too many rows. Dedup on mal_id.*

# %%
BASE_PATH = '/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/'
OUT_PATH  = '/Users/alexandrubudau/Desktop/HCI-PROJECT/cleaned datasets/'
os.makedirs(OUT_PATH, exist_ok=True)

print("=" * 60)
print("CLEANING: details.csv")
print("=" * 60)

df = pd.read_csv(BASE_PATH + 'details.csv')
raw = df.copy()

print(f"\nRaw shape: {df.shape}")
print(df.head(5))

# --- Drop URL/image columns ---
df = df.drop(columns=['url', 'image_url'], errors='ignore')

# --- Drop rows with no title (critical) ---
df = df.dropna(subset=['title'])

# --- Parse dates ---
for col in ['start_date', 'end_date']:
    df[col] = pd.to_datetime(df[col], errors='coerce', utc=True)
    df[col] = df[col].dt.tz_localize(None)

# --- Extract useful date parts ---
df['start_year']  = df['start_date'].dt.year
df['start_month'] = df['start_date'].dt.month

# --- Numeric fields ---
df['score']    = pd.to_numeric(df['score'],    errors='coerce')
df['episodes'] = pd.to_numeric(df['episodes'], errors='coerce')
df['year']     = pd.to_numeric(df['year'],     errors='coerce')
df['rank']     = pd.to_numeric(df['rank'],     errors='coerce')
df['popularity']= pd.to_numeric(df['popularity'], errors='coerce')
df['members']  = pd.to_numeric(df['members'],  errors='coerce')
df['favorites']= pd.to_numeric(df['favorites'],errors='coerce')
df['scored_by']= pd.to_numeric(df['scored_by'],errors='coerce')

# --- Strip text fields ---
df['title']   = df['title'].str.strip()
df['type']    = df['type'].str.strip()
df['status']  = df['status'].str.strip()
df['source']  = df['source'].str.strip()
df['rating']  = df['rating'].str.strip()
df['season']  = df['season'].str.strip()

# --- Fill missing synopsis ---
df['synopsis'] = df['synopsis'].fillna('')

# --- Drop duplicates ---
df = df.drop_duplicates(subset=['mal_id'])

# --- Summary ---
print(f"\n{'─'*60}")
print(f"  Rows before         : {len(raw):,}")
print(f"  Nulls (title)       : {raw['title'].isnull().sum()}")
print(f"  Duplicates removed  : {raw.duplicated(subset=['mal_id']).sum()}")
print(f"  Missing scores      : {df['score'].isnull().sum():,}")
print(f"  Missing episodes    : {df['episodes'].isnull().sum():,}")
print(f"  Rows after          : {len(df):,}")
print(f"{'─'*60}")
print(f"\nType distribution:\n{df['type'].value_counts()}")
print(f"\nStatus distribution:\n{df['status'].value_counts()}")

df.to_csv(OUT_PATH + 'details_clean.csv', index=False)
print("\nSaved → details_clean.csv")
# Out:
# ...
# CLEANING: details.csv
# ...
#
# Raw shape: (28955, 29)
#    mal_id                             title        title_japanese  \
# 0   59356                          -Socket-              -socket-
# 1   56036                            ......                ......
# 2    2928              .hack//G.U. Returner  .HACK//G.U. RETURNER
# 3    3269               .hack//G.U. Trilogy   .hack//G.U. Trilogy
# 4    4469  .hack//G.U. Trilogy: Parody Mode   .hack//G.U. Trilogy
#
#                                                  url  \
# 0       https://myanimelist.net/anime/59356/-Socket-
# 1              https://myanimelist.net/anime/56036/-
# 2  https://myanimelist.net/anime/2928/hack__GU_Re...
# 3  https://myanimelist.net/anime/3269/hack__GU_Tr...
# 4  https://myanimelist.net/anime/4469/hack__GU_Tr...
#
#                                            image_url     type  \
# 0  https://cdn.myanimelist.net/images/anime/1043/...    Movie
# 1  https://cdn.myanimelist.net/images/anime/1057/...    Music
# ...

# %% [markdown]
# *Profiles — User data. username is the critical field. Dates are parsed properly. Gender is capitalised for consistency. All watchlist counts (watching, completed, etc.) are filled with 0 since a missing count really means zero activity, not unknown. Dedup on username.*

# %%
BASE_PATH = '/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/'
OUT_PATH  = '/Users/alexandrubudau/Desktop/HCI-PROJECT/cleaned datasets/'
os.makedirs(OUT_PATH, exist_ok=True)

print("=" * 60)
print("CLEANING: profiles.csv")
print("=" * 60)

df = pd.read_csv(BASE_PATH + 'profiles.csv')
raw = df.copy()

print(f"\nRaw shape: {df.shape}")
print(df.head(5))

# --- Drop rows with no username (critical) ---
df = df.dropna(subset=['username'])
df['username'] = df['username'].str.strip()

# --- Parse dates ---
df['joined']   = pd.to_datetime(df['joined'],   errors='coerce')
df['birthday'] = pd.to_datetime(df['birthday'], errors='coerce')

# --- Extract useful fields ---
df['joined_year'] = df['joined'].dt.year

# --- Normalise gender ---
df['gender'] = df['gender'].str.strip().str.capitalize()

# --- Normalise location ---
df['location'] = df['location'].str.strip()

# --- Watchlist counts: fill 0 where missing ---
for col in ['watching', 'completed', 'on_hold', 'dropped', 'plan_to_watch']:
    df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)

# --- Drop duplicate usernames ---
df = df.drop_duplicates(subset=['username'])

# --- Summary ---
print(f"\n{'─'*60}")
print(f"  Rows before         : {len(raw):,}")
print(f"  Nulls (username)    : {raw['username'].isnull().sum()}")
print(f"  Duplicates removed  : {raw.duplicated(subset=['username']).sum()}")
print(f"  Missing gender      : {df['gender'].isnull().sum():,}")
print(f"  Missing location    : {df['location'].isnull().sum():,}")
print(f"  Missing joined      : {df['joined'].isnull().sum():,}")
print(f"  Rows after          : {len(df):,}")
print(f"{'─'*60}")
print(f"\nGender distribution:\n{df['gender'].value_counts(dropna=False)}")
print(f"\nTop 10 locations:\n{df['location'].value_counts().head(10)}")

df.to_csv(OUT_PATH + 'profiles_clean.csv', index=False)
print("\nSaved → profiles_clean.csv")
# Out:
# ...
# CLEANING: profiles.csv
# ...
#
# Raw shape: (337155, 10)
#       username  gender birthday       location        joined watching  \
# 0    ishikawas     NaN      NaN    South Korea           NaN      NaN
# 1         CKK2     NaN      NaN  United States   Dec 1, 2018        3
# 2  --------788  Female      NaN         Mexico   Oct 4, 2022        1
# 3   potatoaris     NaN      NaN          Spain   Oct 2, 2018        5
# 4    Rinrintan     NaN      NaN          Japan  May 12, 2019       20
#
#   completed on_hold dropped plan_to_watch
# 0       NaN     NaN     NaN           NaN
# 1       182      15       0           405
# 2        64       0       0             1
# 3         1       0       0             4
# 4       311      40      16            34
#
# ────────────────────────────────────────────────────────────
#   Rows before         : 337,155
#   Nulls (username)    : 1
#   Duplicates removed  : 0
#   Missing gender      : 170,875
#   Missing location    : 0
# ...

# %% [markdown]
# *Recommendations — Very simple structure. Drop nulls on both ID columns. Remove self-recommendations where an anime recommends itself (data error). Dedup on the (mal_id, recommendation_mal_id) pair.*

# %%
BASE_PATH = '/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/'
OUT_PATH  = '/Users/alexandrubudau/Desktop/HCI-PROJECT/cleaned datasets/'
os.makedirs(OUT_PATH, exist_ok=True)

print("=" * 60)
print("CLEANING: recommendations.csv")
print("=" * 60)

df = pd.read_csv(BASE_PATH + 'recommendations.csv')
raw = df.copy()

print(f"\nRaw shape: {df.shape}")
print(df.head(5))

# --- Drop nulls on critical IDs ---
df = df.dropna(subset=['mal_id', 'recommendation_mal_id'])

# --- Remove self-recommendations ---
self_recs = (df['mal_id'] == df['recommendation_mal_id']).sum()
print(f"\n  Self-recommendations found: {self_recs}")
df = df[df['mal_id'] != df['recommendation_mal_id']]

# --- Drop duplicates ---
df = df.drop_duplicates(subset=['mal_id', 'recommendation_mal_id'])

# --- Summary ---
print(f"\n{'─'*60}")
print(f"  Rows before              : {len(raw):,}")
print(f"  Nulls removed            : {raw.isnull().any(axis=1).sum()}")
print(f"  Self-recommendations     : {self_recs}")
print(f"  Duplicates removed       : {raw.duplicated(subset=['mal_id','recommendation_mal_id']).sum()}")
print(f"  Rows after               : {len(df):,}")
print(f"{'─'*60}")
print(f"\nMost recommended anime (top 10):")
print(df['recommendation_mal_id'].value_counts().head(10))

df.to_csv(OUT_PATH + 'recommendations_clean.csv', index=False)
print("\nSaved → recommendations_clean.csv")
# Out:
# ...
# CLEANING: recommendations.csv
# ...
#
# Raw shape: (105249, 2)
#    mal_id  recommendation_mal_id
# 0    3269                    317
# 1    3269                   6922
# 2    3269                    299
# 3    3269                   3446
# 4    3269                   5681
#
#   Self-recommendations found: 0
#
# ────────────────────────────────────────────────────────────
#   Rows before              : 105,249
#   Nulls removed            : 0
#   Self-recommendations     : 0
#   Duplicates removed       : 0
#   Rows after               : 105,249
# ────────────────────────────────────────────────────────────
#
# Most recommended anime (top 10):
# recommendation_mal_id
# 30       300
# 9756     293
# 1575     258
# 2001     238
# 918      237
# 1535     234
# 6547     206
# 16498    201
# 5680     195
# 226      194
# Name: count, dtype: int64
#
# Saved → recommendations_clean.csv

# %% [markdown]
#  *Stats — Contains vote counts and percentages for each score (1–10) per anime. All numeric columns are coerced and filled with 0. We add a computed_total column that sums up all status counts as a validation check against the recorded total. Dedup on mal_id.*

# %%
BASE_PATH = '/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/'
OUT_PATH  = '/Users/alexandrubudau/Desktop/HCI-PROJECT/cleaned datasets/'
os.makedirs(OUT_PATH, exist_ok=True)

print("=" * 60)
print("CLEANING: stats.csv")
print("=" * 60)

df = pd.read_csv(BASE_PATH + 'stats.csv')
raw = df.copy()

print(f"\nRaw shape: {df.shape}")
print(df.head(5))

# --- Drop rows with no mal_id ---
df = df.dropna(subset=['mal_id'])

# --- Numeric: status count columns ---
for col in ['watching', 'completed', 'on_hold', 'dropped', 'plan_to_watch', 'total']:
    df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)

# --- Numeric: score vote and percentage columns ---
vote_cols = [c for c in df.columns if 'votes' in c or 'percentage' in c]
for col in vote_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0)

# --- Add validation column: computed total vs recorded total ---
df['computed_total'] = df[['watching','completed','on_hold','dropped','plan_to_watch']].sum(axis=1)
mismatches = (df['computed_total'] != df['total']).sum()
print(f"\n  Rows where computed_total != total: {mismatches:,}")

# --- Drop duplicates ---
df = df.drop_duplicates(subset=['mal_id'])

# --- Summary ---
print(f"\n{'─'*60}")
print(f"  Rows before         : {len(raw):,}")
print(f"  Nulls (mal_id)      : {raw['mal_id'].isnull().sum()}")
print(f"  Duplicates removed  : {raw.duplicated(subset=['mal_id']).sum()}")
print(f"  Rows after          : {len(df):,}")
print(f"{'─'*60}")
print(f"\nTop 10 most completed anime (by completed count):")
print(df[['mal_id','completed']].sort_values('completed', ascending=False).head(10))

df.to_csv(OUT_PATH + 'stats_clean.csv', index=False)
print("\nSaved → stats_clean.csv")
# Out:
# ...
# CLEANING: stats.csv
# ...
#
# Raw shape: (28955, 27)
#    mal_id  watching  completed  on_hold  dropped  plan_to_watch  total  \
# 0   59356         7        146        4       20             20    197
# 1   56036        21        770        8       29            113    941
# 2    2928       451      14953      302      349           6472  22527
# 3    3269       726      22790      452      537           9762  34267
# 4    4469       241       6918      182      266           3528  11135
#
#    score_1_votes  score_1_percentage  score_2_votes  ...  score_6_votes  \
# 0            2.0                 2.2            0.0  ...           33.0
# 1            5.0                 1.0            6.0  ...          138.0
# 2          101.0                 1.0           93.0  ...         2054.0
# 3          120.0                 0.8          156.0  ...         2457.0
# 4           83.0                 1.9          104.0  ...          888.0
#
# ...

# %% [markdown]
# *Person_voice_works — Links voice actors to characters and anime. All three ID columns are critical so we drop nulls on all of them. role and language are normalised for consistency (strip + title case). Full row dedup.*

# %%
BASE_PATH = '/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/'
OUT_PATH  = '/Users/alexandrubudau/Desktop/HCI-PROJECT/cleaned datasets/'
os.makedirs(OUT_PATH, exist_ok=True)

print("=" * 60)
print("CLEANING: person_voice_works.csv")
print("=" * 60)

df = pd.read_csv(BASE_PATH + 'person_voice_works.csv')
raw = df.copy()

print(f"\nRaw shape: {df.shape}")
print(df.head(5))

# --- Drop nulls on critical IDs ---
df = df.dropna(subset=['person_mal_id', 'anime_mal_id', 'character_mal_id'])

# --- Normalise role and language ---
df['role']     = df['role'].str.strip().str.title()
df['language'] = df['language'].str.strip()

# --- Drop duplicates ---
df = df.drop_duplicates()

# --- Summary ---
print(f"\n{'─'*60}")
print(f"  Rows before         : {len(raw):,}")
print(f"  Nulls removed       : {raw.isnull().any(axis=1).sum()}")
print(f"  Duplicates removed  : {raw.duplicated().sum()}")
print(f"  Rows after          : {len(df):,}")
print(f"{'─'*60}")
print(f"\nRole distribution:\n{df['role'].value_counts()}")
print(f"\nLanguage distribution:\n{df['language'].value_counts().head(10)}")

df.to_csv(OUT_PATH + 'person_voice_works_clean.csv', index=False)
print("\nSaved → person_voice_works_clean.csv")
# Out:
# ...
# CLEANING: person_voice_works.csv
# ...
#
# Raw shape: (489516, 5)
#    person_mal_id        role  anime_mal_id  character_mal_id  language
# 0              1        Main         55830              2514  Japanese
# 1              1  Supporting         60602              2822  Japanese
# 2              1  Supporting         59229            140499  Japanese
# 3              1  Supporting         60427            275856  Japanese
# 4              1  Supporting         62067            190335  Japanese
#
# ────────────────────────────────────────────────────────────
#   Rows before         : 489,516
#   Nulls removed       : 0
#   Duplicates removed  : 951
#   Rows after          : 488,565
# ────────────────────────────────────────────────────────────
#
# Role distribution:
# role
# Supporting    389385
# Main           99180
# Name: count, dtype: int64
#
# Language distribution:
# language
# Japanese           203519
# English             94094
# French              43340
# ...

# %% [markdown]
# *Person_details — Like characters but for real people. We drop URL columns, parse birthday as datetime and extract birth_year. favorites filled with 0. relevant_location stripped. Dedup on person_mal_id.*

# %%
BASE_PATH = '/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/'
OUT_PATH  = '/Users/alexandrubudau/Desktop/HCI-PROJECT/cleaned datasets/'
os.makedirs(OUT_PATH, exist_ok=True)

print("=" * 60)
print("CLEANING: person_details.csv")
print("=" * 60)

df = pd.read_csv(BASE_PATH + 'person_details.csv')
raw = df.copy()

print(f"\nRaw shape: {df.shape}")
print(df.head(5))

# --- Drop URL columns (not useful for analysis) ---
df = df.drop(columns=['url', 'website_url', 'image_url'], errors='ignore')

# --- Drop rows with no name (critical) ---
df = df.dropna(subset=['name'])

# --- Strip text fields ---
df['name']              = df['name'].str.strip()
df['given_name']        = df['given_name'].str.strip()
df['family_name']       = df['family_name'].str.strip()
df['relevant_location'] = df['relevant_location'].str.strip()

# --- Parse birthday ---
df['birthday'] = pd.to_datetime(df['birthday'], errors='coerce', utc=True)
df['birthday'] = df['birthday'].dt.tz_localize(None)
df['birth_year'] = df['birthday'].dt.year

# --- Favorites: fill 0 ---
df['favorites'] = pd.to_numeric(df['favorites'], errors='coerce').fillna(0).astype(int)

# --- Drop duplicates ---
df = df.drop_duplicates(subset=['person_mal_id'])

# --- Summary ---
print(f"\n{'─'*60}")
print(f"  Rows before              : {len(raw):,}")
print(f"  Nulls (name)             : {raw['name'].isnull().sum()}")
print(f"  Missing birthday         : {df['birthday'].isnull().sum():,}")
print(f"  Missing relevant_location: {df['relevant_location'].isnull().sum():,}")
print(f"  Duplicates removed       : {raw.duplicated(subset=['person_mal_id']).sum()}")
print(f"  Rows after               : {len(df):,}")
print(f"{'─'*60}")
print(f"\nTop 10 most favourited people:")
print(df[['name','favorites']].sort_values('favorites', ascending=False).head(10))

df.to_csv(OUT_PATH + 'person_details_clean.csv', index=False)
print("\nSaved → person_details_clean.csv")
# Out:
# ...
# CLEANING: person_details.csv
# ...
#
# Raw shape: (76699, 10)
#    person_mal_id                                                url  \
# 0              1     https://myanimelist.net/people/1/Tomokazu_Seki
# 1              2   https://myanimelist.net/people/2/Tomokazu_Sugita
# 2              3    https://myanimelist.net/people/3/Satsuki_Yukino
# 3              4        https://myanimelist.net/people/4/Aya_Hirano
# 4              5  https://myanimelist.net/people/5/Kenichi_Suzumura
#
#                website_url                                          image_url  \
# 0                      NaN  https://cdn.myanimelist.net/images/voiceactors...
# 1      https://agrs.co.jp/  https://cdn.myanimelist.net/images/voiceactors...
# 2                      NaN  https://cdn.myanimelist.net/images/voiceactors...
# 3     http://ayahirano.jp/  https://cdn.myanimelist.net/images/voiceactors...
# 4  https://intention-k.com  https://cdn.myanimelist.net/images/voiceactors...
#
# ...

# %% [markdown]
# *Person_anime_works — Links people to anime via their position (e.g. director, theme song). Both ID columns are critical so nulls are dropped on them. position is stripped. Full row dedup.*

# %%
BASE_PATH = '/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/'
OUT_PATH  = '/Users/alexandrubudau/Desktop/HCI-PROJECT/cleaned datasets/'
os.makedirs(OUT_PATH, exist_ok=True)

print("=" * 60)
print("CLEANING: person_anime_works.csv")
print("=" * 60)

df = pd.read_csv(BASE_PATH + 'person_anime_works.csv')
raw = df.copy()

print(f"\nRaw shape: {df.shape}")
print(df.head(5))

# --- Drop nulls on critical IDs ---
df = df.dropna(subset=['person_mal_id', 'anime_mal_id'])

# --- Normalise position text ---
df['position'] = df['position'].str.strip()

# --- Drop duplicates ---
df = df.drop_duplicates()

# --- Summary ---
print(f"\n{'─'*60}")
print(f"  Rows before         : {len(raw):,}")
print(f"  Nulls removed       : {raw.isnull().any(axis=1).sum()}")
print(f"  Duplicates removed  : {raw.duplicated().sum()}")
print(f"  Rows after          : {len(df):,}")
print(f"{'─'*60}")
print(f"\nTop 10 position types:")
print(df['position'].value_counts().head(10))
print(f"\nTop 10 most prolific people (by anime works):")
print(df['person_mal_id'].value_counts().head(10))

df.to_csv(OUT_PATH + 'person_anime_works_clean.csv', index=False)
print("\nSaved → person_anime_works_clean.csv")
# Out:
# ...
# CLEANING: person_anime_works.csv
# ...
#
# Raw shape: (458091, 3)
#    person_mal_id                     position  anime_mal_id
# 0              1       Theme Song Performance          3080
# 1              1    Inserted Song Performance         15699
# 2              1  Theme Song Performance (OP)           247
# 3              1       Theme Song Performance           258
# 4              1  Theme Song Performance (ED)         34825
#
# ────────────────────────────────────────────────────────────
#   Rows before         : 458,091
#   Nulls removed       : 0
#   Duplicates removed  : 0
#   Rows after          : 458,091
# ────────────────────────────────────────────────────────────
#
# Top 10 position types:
# position
# Key Animation           29344
# Producer                15151
# Planning                 9589
# Original Creator         9147
# Key Animation (ep 1)     8144
# Music                    8042
# Director                 7805
# In-Between Animation     7456
# ...

# %% [markdown]
# Favs — User favourites table. All three columns (username, fav_type, id) are critical. fav_type is lowercased for consistency (e.g. Anime → anime). Dedup on the full (username, fav_type, id) combination.

# %%
BASE_PATH = '/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/'
OUT_PATH  = '/Users/alexandrubudau/Desktop/HCI-PROJECT/cleaned datasets/'
os.makedirs(OUT_PATH, exist_ok=True)

print("=" * 60)
print("CLEANING: favs.csv")
print("=" * 60)

df = pd.read_csv(BASE_PATH + 'favs.csv')
raw = df.copy()

print(f"\nRaw shape: {df.shape}")
print(df.head(5))

# --- Drop nulls ---
df = df.dropna(subset=['username', 'fav_type', 'id'])

# --- Normalise text ---
df['username'] = df['username'].str.strip()
df['fav_type'] = df['fav_type'].str.strip().str.lower()

# --- Drop duplicates ---
df = df.drop_duplicates(subset=['username', 'fav_type', 'id'])

# --- Summary ---
print(f"\n{'─'*60}")
print(f"  Rows before         : {len(raw):,}")
print(f"  Nulls removed       : {raw.isnull().any(axis=1).sum()}")
print(f"  Duplicates removed  : {raw.duplicated(subset=['username','fav_type','id']).sum()}")
print(f"  Rows after          : {len(df):,}")
print(f"{'─'*60}")
print(f"\nFav type distribution:\n{df['fav_type'].value_counts()}")
print(f"\nTop 10 users by number of favourites:")
print(df.groupby('username')['id'].count().sort_values(ascending=False).head(10))

df.to_csv(OUT_PATH + 'favs_clean.csv', index=False)
print("\nSaved → favs_clean.csv")
# Out:
# ...
# CLEANING: favs.csv
# ...
#
# Raw shape: (4178747, 3)
#     username fav_type     id
# 0  ishikawas    anime  45649
# 1  ishikawas    anime  38680
# 2  ishikawas    anime    795
# 3  ishikawas    anime  37510
# 4  ishikawas    anime    820
#
# ────────────────────────────────────────────────────────────
#   Rows before         : 4,178,747
#   Nulls removed       : 4
#   Duplicates removed  : 0
#   Rows after          : 4,178,743
# ────────────────────────────────────────────────────────────
#
# Fav type distribution:
# fav_type
# character    1598040
# anime        1531853
# people        862186
# company       186664
# Name: count, dtype: int64
#
# Top 10 users by number of favourites:
# username
# bangkokslice     81
# Syrian187        80
# Retro8bit        80
# kizumi91         80
# Kyotosomo        80
# _MushiRock11_    80
# RhyOverHeaven    80
# J0tar0u          80
# GrumbleDango     80
# Atrfan1          80
# Name: id, dtype: int64
#
# Saved → favs_clean.csv

# %% [markdown]
# Character_nicknames — Same logic as person_alternate_names. Drop nulls, strip whitespace, remove empty strings after stripping, dedup on (character_mal_id, nickname).

# %%
BASE_PATH = '/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/'
OUT_PATH  = '/Users/alexandrubudau/Desktop/HCI-PROJECT/cleaned datasets/'
os.makedirs(OUT_PATH, exist_ok=True)

print("=" * 60)
print("CLEANING: character_nicknames.csv")
print("=" * 60)

df = pd.read_csv(BASE_PATH + 'character_nicknames.csv')
raw = df.copy()

print(f"\nRaw shape: {df.shape}")
print(df.head(5))

# --- Drop nulls ---
df = df.dropna(subset=['character_mal_id', 'nickname'])

# --- Normalise nickname ---
df['nickname'] = df['nickname'].str.strip()
df = df[df['nickname'] != '']

# --- Drop duplicates ---
df = df.drop_duplicates(subset=['character_mal_id', 'nickname'])

# --- Summary ---
print(f"\n{'─'*60}")
print(f"  Rows before         : {len(raw):,}")
print(f"  Nulls removed       : {raw.isnull().any(axis=1).sum()}")
print(f"  Duplicates removed  : {raw.duplicated(subset=['character_mal_id','nickname']).sum()}")
print(f"  Rows after          : {len(df):,}")
print(f"{'─'*60}")
print(f"\nNicknames per character (stats):")
print(df.groupby('character_mal_id')['nickname'].count().describe())
print(f"\nTop 10 characters with most nicknames:")
print(df.groupby('character_mal_id')['nickname'].count().sort_values(ascending=False).head(10))

df.to_csv(OUT_PATH + 'character_nicknames_clean.csv', index=False)
print("\nSaved → character_nicknames_clean.csv")
# Out:
# ...
# CLEANING: character_nicknames.csv
# ...
#
# Raw shape: (37080, 2)
#    character_mal_id              nickname
# 0            280205              Hikaruko
# 1            280129              Hinacchi
# 2            280127         Bertha Willis
# 3            280066                 Jimmy
# 4            280059  Full Body Red Square
#
# ────────────────────────────────────────────────────────────
#   Rows before         : 37,080
#   Nulls removed       : 16
#   Duplicates removed  : 102
#   Rows after          : 36,960
# ────────────────────────────────────────────────────────────
#
# Nicknames per character (stats):
# count    30265.000000
# mean         1.221213
# std          0.612776
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max         10.000000
# Name: nickname, dtype: float64
#
# Top 10 characters with most nicknames:
# character_mal_id
# 17244     10
# 2030       9
# 256883     8
# 80891      8
# 13784      8
# 670        8
# ...

# %% [markdown]
# Character_anime_works — Links characters to the anime they appear in. Both ID columns are critical. role is normalised to title case. Dedup on (anime_mal_id, character_mal_id) since a character should only appear once per anime.

# %%
BASE_PATH = '/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/'
OUT_PATH  = '/Users/alexandrubudau/Desktop/HCI-PROJECT/cleaned datasets/'
os.makedirs(OUT_PATH, exist_ok=True)

print("=" * 60)
print("CLEANING: character_anime_works.csv")
print("=" * 60)

df = pd.read_csv(BASE_PATH + 'character_anime_works.csv')
raw = df.copy()

print(f"\nRaw shape: {df.shape}")
print(df.head(5))

# --- Drop nulls on IDs ---
df = df.dropna(subset=['anime_mal_id', 'character_mal_id'])

# --- Normalise text ---
df['character_name'] = df['character_name'].str.strip()
df['role']           = df['role'].str.strip().str.title()

# --- Drop duplicates ---
df = df.drop_duplicates(subset=['anime_mal_id', 'character_mal_id'])

# --- Summary ---
print(f"\n{'─'*60}")
print(f"  Rows before         : {len(raw):,}")
print(f"  Nulls removed       : {raw.isnull().any(axis=1).sum()}")
print(f"  Duplicates removed  : {raw.duplicated(subset=['anime_mal_id','character_mal_id']).sum()}")
print(f"  Rows after          : {len(df):,}")
print(f"{'─'*60}")
print(f"\nRole distribution:\n{df['role'].value_counts()}")
print(f"\nTop 10 anime by number of characters:")
print(df.groupby('anime_mal_id')['character_mal_id'].count().sort_values(ascending=False).head(10))

df.to_csv(OUT_PATH + 'character_anime_works_clean.csv', index=False)
print("\nSaved → character_anime_works_clean.csv")
# Out:
# ...
# CLEANING: character_anime_works.csv
# ...
#
# Raw shape: (236816, 4)
#    anime_mal_id  character_mal_id character_name        role
# 0          2928              5781          Atoli        Main
# 1          2928                33          Haseo        Main
# 2          2928                32           Ovan        Main
# 3          2928                34          Shino        Main
# 4          2928              5785           Aina  Supporting
#
# ────────────────────────────────────────────────────────────
#   Rows before         : 236,816
#   Nulls removed       : 0
#   Duplicates removed  : 0
#   Rows after          : 236,816
# ────────────────────────────────────────────────────────────
#
# Role distribution:
# role
# Supporting    186285
# Main           50531
# Name: count, dtype: int64
#
# Top 10 anime by number of characters:
# anime_mal_id
# 235      1927
# 21       1470
# 1960     1059
# 527       481
# 1735      440
# 1564      399
# 7307      393
# 2076      393
# 40351     390
# ...

# %% [markdown]
# Ratings — By far the largest file (124M+ rows) so it's processed in chunks to avoid memory crashes. For each chunk: drop nulls on username and anime_id, validate status against a known set of valid values, validate score is between 0–10, fill missing counts with 0. After all chunks are concatenated, a final global dedup is done on (username, anime_id) since a user should only have one rating per anime.

# %%
BASE_PATH = '/Users/alexandrubudau/Desktop/HCI-PROJECT/datasets/'
OUT_PATH  = '/Users/alexandrubudau/Desktop/HCI-PROJECT/cleaned datasets/'
os.makedirs(OUT_PATH, exist_ok=True)

print("=" * 60)
print("CLEANING: ratings.csv  [chunk processing]")
print("=" * 60)

CHUNK_SIZE = 5_000_000
VALID_STATUSES = {'watching', 'completed', 'on_hold', 'dropped', 'plan_to_watch'}

chunks_clean = []
total_raw    = 0
total_clean  = 0
chunk_num    = 0

for chunk in pd.read_csv(BASE_PATH + 'ratings.csv', chunksize=CHUNK_SIZE):
    chunk_num  += 1
    total_raw  += len(chunk)

    # --- Drop nulls on critical fields ---
    chunk = chunk.dropna(subset=['username', 'anime_id'])

    # --- Normalise status ---
    chunk['status'] = chunk['status'].str.strip().str.lower()
    chunk = chunk[chunk['status'].isin(VALID_STATUSES)]

    # --- Validate score (must be 0–10 or NaN) ---
    chunk['score'] = pd.to_numeric(chunk['score'], errors='coerce')
    chunk = chunk[(chunk['score'].isna()) | (chunk['score'].between(0, 10))]

    # --- Normalise is_rewatching ---
    chunk['is_rewatching'] = chunk['is_rewatching'].fillna(0).astype(int)

    # --- Fill missing episode count ---
    chunk['num_watched_episodes'] = pd.to_numeric(
        chunk['num_watched_episodes'], errors='coerce'
    ).fillna(0).astype(int)

    # --- Drop duplicates within chunk ---
    chunk = chunk.drop_duplicates(subset=['username', 'anime_id'])

    total_clean += len(chunk)
    chunks_clean.append(chunk)

    print(f"  Chunk {chunk_num:>3} — raw: {len(chunk) + (total_raw - total_clean - len(chunk)):,} → kept: {len(chunk):,}")

print("\nConcatenating all chunks...")
df = pd.concat(chunks_clean, ignore_index=True)

# --- Final global dedup across chunks ---
before_global_dedup = len(df)
df = df.drop_duplicates(subset=['username', 'anime_id'])
print(f"  Cross-chunk duplicates removed: {before_global_dedup - len(df):,}")

# --- Summary ---
print(f"\n{'─'*60}")
print(f"  Total raw rows    : {total_raw:,}")
print(f"  Total clean rows  : {len(df):,}")
print(f"  Total removed     : {total_raw - len(df):,}")
print(f"{'─'*60}")
print(f"\nStatus distribution:\n{df['status'].value_counts()}")
print(f"\nScore distribution:\n{df['score'].value_counts().sort_index()}")

df.to_csv(OUT_PATH + 'ratings_clean.csv', index=False)
print("\nSaved → ratings_clean.csv")
# Out:
# ...
# CLEANING: ratings.csv  [chunk processing]
# ...
#   Chunk   1 — raw: 151 → kept: 4,999,849
#   Chunk   2 — raw: 681 → kept: 4,999,470
#   Chunk   3 — raw: 2,293 → kept: 4,998,388
#   Chunk   4 — raw: 3,072 → kept: 4,999,221
#   Chunk   5 — raw: 5,324 → kept: 4,997,748
#   Chunk   6 — raw: 5,903 → kept: 4,999,421
#   Chunk   7 — raw: 6,254 → kept: 4,999,649
#   Chunk   8 — raw: 6,542 → kept: 4,999,712
#   Chunk   9 — raw: 6,571 → kept: 4,999,971
#   Chunk  10 — raw: 6,670 → kept: 4,999,901
#   Chunk  11 — raw: 7,628 → kept: 4,999,042
#   Chunk  12 — raw: 7,778 → kept: 4,999,850
#   Chunk  13 — raw: 10,117 → kept: 4,997,661
#   Chunk  14 — raw: 10,880 → kept: 4,999,237
#   Chunk  15 — raw: 11,187 → kept: 4,999,693
#   Chunk  16 — raw: 11,414 → kept: 4,999,773
#   Chunk  17 — raw: 11,426 → kept: 4,999,988
#   Chunk  18 — raw: 12,755 → kept: 4,998,671
#   Chunk  19 — raw: 13,293 → kept: 4,999,462
#   Chunk  20 — raw: 13,622 → kept: 4,999,671
#   Chunk  21 — raw: 13,853 → kept: 4,999,769
# ...

# %% [markdown]
# ## DATA IS CLEANED, TIME TO GET DOWN TO ANALYSE AND COMPREHEND THE MEANING OF THESE ENORMOUS DATASETS

# %%
import ast
import warnings
import matplotlib.ticker as ticker

warnings.filterwarnings('ignore')

CLEAN_PATH = '/Users/alexandrubudau/Desktop/HCI-PROJECT/cleaned datasets/'
OUT_PATH   = '/Users/alexandrubudau/Desktop/HCI-PROJECT/cleaned datasets/'

df = pd.read_csv(CLEAN_PATH + "details_clean.csv")

# we keep only rows with valid start year
df = df.dropna(subset=['start_year'])
df['start_year'] = df['start_year'].astype(int)

# we decide to keep only a meaningful range (1960 onwards)
df = df[df['start_year'] >= 1960]

# we add a decade column
df['decade'] = (df['start_year'] // 10 ) * 10

# we focus on the main types
main_types = ['TV', 'Movie', 'OVA', 'ONA', 'Special']
df_types = df[df['type'].isin(main_types)]

# then count per year per type
yearly_type = (
    df_types.groupby(['start_year', 'type'])
    .size()
    .reset_index(name='count')
)

# pivot for plotting
pivot = yearly_type.pivot(index='start_year', columns='type', values='count').fillna(0)

# and now we plot
fig, ax = plt.subplots(figsize=(16, 7))

colors = {
    'TV'      : '#E63946',
    'Movie'   : '#457B9D',
    'OVA'     : '#2A9D8F',
    'ONA'     : '#E9C46A',
    'Special' : '#A8DADC'
}

for t in main_types:
    if t in pivot.columns:
        ax.plot(pivot.index, pivot[t], label=t,
                color=colors[t], linewidth=2.5, marker='o', markersize=3)

# Annotate key events
ax.axvline(x=1995, color='gray', linestyle='--', alpha=0.5)
ax.text(1995.5, ax.get_ylim()[1] * 0.95, 'Evangelion\nera (1995)',
        fontsize=8, color='gray')

ax.axvline(x=2006, color='gray', linestyle='--', alpha=0.5)
ax.text(2006.5, ax.get_ylim()[1] * 0.85, 'ONA boom\n(2006)',
        fontsize=8, color='gray')

ax.set_title('Anime Production by Type Over Time (1960–present)',
             fontsize=16, fontweight='bold', pad=20)
ax.set_xlabel('Year', fontsize=12)
ax.set_ylabel('Number of Anime', fontsize=12)
ax.legend(title='Type', fontsize=10)
ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
ax.grid(axis='y', linestyle='--', alpha=0.4)
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig(OUT_PATH + 'chart1_anime_production_by_type.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Anime Production by Type Over Time
#
# This chart tracks how many anime were produced each year from 1960
# to present, broken down by format.
#
# **What the data tells us:**
# - **Movies dominated the early era (1960s–1980s)** — before home video
#   existed, cinema was the only way to distribute anime
# - **OVA exploded in the 1980s** — the home video boom allowed studios to
#   release directly to consumers, bypassing TV networks entirely
# - **TV series surged after 1995** — the Evangelion era triggered a massive
#   wave of TV productions that never stopped growing, peaking around 2015–2017
# - **ONA emerged after 2006** — the rise of streaming platforms like
#   Niconico and later Crunchyroll created a new format, which by 2019
#   nearly matched TV in volume
# - **The sharp drop after 2023** is not a real decline — the dataset was
#   collected mid-cycle, so recent years are simply incomplete
#
# **Conclusion:** Each technological shift — home video, TV deregulation,
# streaming — created a new dominant format, completely reshaping how
# anime is produced and consumed.

# %%
def parse_list_col(val):
    try:
        parsed = ast.literal_eval(val)
        if isinstance(parsed, list):
            return parsed
    except:
        pass
    return []

df['genres_parsed'] = df['genres'].apply(parse_list_col)

# Explode genres
df_genres = df[['decade', 'genres_parsed']].explode('genres_parsed')
df_genres = df_genres.rename(columns={'genres_parsed': 'genre'})
df_genres = df_genres[df_genres['genre'].notna() & (df_genres['genre'] != '')]

# Count per decade per genre
decade_genre = (
    df_genres.groupby(['decade', 'genre'])
    .size()
    .reset_index(name='count')
)

# Normalise as % of total anime that decade
total_per_decade = df.groupby('decade').size().reset_index(name='total')
decade_genre = decade_genre.merge(total_per_decade, on='decade')
decade_genre['pct'] = (decade_genre['count'] / decade_genre['total'] * 100).round(2)

# Top 8 genres by total count
top_genres = (
    decade_genre.groupby('genre')['count']
    .sum()
    .sort_values(ascending=False)
    .head(8)
    .index.tolist()
)

df_top = decade_genre[decade_genre['genre'].isin(top_genres)]
pivot2 = df_top.pivot(index='decade', columns='genre', values='pct').fillna(0)

# --- Plot ---
palette = [
    '#E63946', '#457B9D', '#2A9D8F', '#E9C46A',
    '#F4A261', '#A8DADC', '#6D2B8C', '#2B9348'
]

fig, ax = plt.subplots(figsize=(16, 7))

ax.stackplot(
    pivot2.index,
    [pivot2[genre] for genre in pivot2.columns],
    labels=pivot2.columns,
    colors=palette,
    alpha=0.85
)

ax.set_title('Genre Popularity Trends by Decade (% of all anime)',
             fontsize=16, fontweight='bold', pad=20)
ax.set_xlabel('Decade', fontsize=12)
ax.set_ylabel('% of Anime in that Decade', fontsize=12)
ax.legend(title='Genre', fontsize=10, bbox_to_anchor=(1.01, 1), loc='upper left')
ax.xaxis.set_major_locator(ticker.MultipleLocator(10))
ax.grid(axis='y', linestyle='--', alpha=0.3)
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig(OUT_PATH + 'chart2_genre_trends_area.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Genre Popularity Trends by Decade
#
# This stacked area chart shows how the genre composition of anime
# changed across decades, measured as a percentage of all anime
# produced that decade. Note: percentages exceed 100% because
# anime can belong to multiple genres simultaneously.
#
# **What the data tells us:**
# - **Comedy was the dominant genre of the 1980s and 1990s** — making up
#   a huge share of all production during the OVA and early TV boom
# - **Sci-Fi peaked in the 1990s** then steadily declined — reflecting the
#   cultural moment of shows like Evangelion and Ghost in the Shell
# - **Hentai had a notable spike in the 1990s–2000s** driven by the OVA
#   format which had fewer broadcast restrictions, then shrank sharply
#   as streaming platforms enforced content policies
# - **Fantasy and Drama grew steadily from 2000 onwards** — replacing
#   Sci-Fi as the dominant storytelling genres in modern anime
# - **The overall mix shrank in 2010** before recovering — this dip
#   coincides with the post-2008 economic crisis which reduced
#   production budgets industry-wide
#
# **Conclusion:** Anime genres are not static — they mirror broader
# cultural, technological and economic shifts across each decade.

# %%
df = pd.read_csv(CLEAN_PATH + 'details_clean.csv')

# keeping only rows with both score and members
df_scored = df.dropna(subset=['score', 'members'])

fig, ax = plt.subplots(figsize=(14, 7))

# log scale on members to handle outliers (huge shows like One Piece)
ax.scatter(
    np.log10(df_scored['members']),
    df_scored['score'],
    alpha=0.25,
    s=15,
    color='#457B9D',
    edgecolors='none'
)

# trend line
z = np.polyfit(np.log10(df_scored['members']), df_scored['score'], 1)
p = np.poly1d(z)
x_line = np.linspace(np.log10(df_scored['members']).min(),
                     np.log10(df_scored['members']).max(), 300)
ax.plot(x_line, p(x_line), color='#E63946', linewidth=2.5, label='Trend line')

# calculations for the correlation value
corr = df_scored['members'].corr(df_scored['score'])
ax.text(0.05, 0.92, f'Pearson r = {corr:.2f}',
        transform=ax.transAxes, fontsize=12,
        bbox=dict(boxstyle='round', facecolor='white', alpha=0.7))

# annotations for a few famous outliers
top_members = df_scored.nlargest(5, 'members')
for _, row in top_members.iterrows():
    ax.annotate(
        row['title'],
        xy=(np.log10(row['members']), row['score']),
        xytext=(8, 4), textcoords='offset points',
        fontsize=7, color='#333333'
    )

# fixing x-axis ticks to show actual member counts
x_ticks = [3, 4, 5, 6, 7]
ax.set_xticks(x_ticks)
ax.set_xticklabels([f'{10**x:,.0f}' for x in x_ticks])

ax.set_title('Does Popularity Guarantee Quality?\nMembers vs Score (log scale)',
             fontsize=16, fontweight='bold', pad=20)
ax.set_xlabel('Number of Members (log scale)', fontsize=12)
ax.set_ylabel('Score', fontsize=12)
ax.legend(fontsize=10)
ax.grid(linestyle='--', alpha=0.4)
plt.tight_layout()
plt.savefig(OUT_PATH + 'chart3_popularity_vs_score.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Does Popularity Guarantee Quality?
#
# This chart explores whether the most-watched anime are also the most loved.
#
# Each dot represents one anime — its position on the x-axis shows how many
# members have it on their list, and its position on the y-axis shows its score.
#
# **What the data tells us:**
# - The Pearson r = 0.39 indicates a **moderate positive correlation** —
#   popularity and quality are related, but far from the same thing
# - The wide spread of dots shows that **many unpopular anime score just as
#   high** as popular ones — hidden gems exist
# - The most popular anime (Fullmetal Alchemist: Brotherhood, Death Note,
#   Shingeki no Kyojin) tend to cluster at the top right — both popular AND
#   highly rated
# - At low member counts, scores vary wildly (2.0 to 9.0) — with little
#   exposure, quality is unpredictable
# - As popularity grows, scores converge towards 6–8 — suggesting that
#   word-of-mouth tends to filter out the worst anime
#
# **Conclusion:** Popularity is a weak but real signal of quality.
# A highly popular anime is *likely* good, but popularity alone is
# not enough to guarantee it.

# %%
main_types = ['TV Series', 'Movies', 'OVA', 'ONA', 'Special', 'Music']
df_types = df_scored[df_scored['type'].isin(main_types)]

# mean score and count per type
type_stats = (
    df_types.groupby('type')['score']
    .agg(['mean', 'median', 'count', 'std'])
    .reset_index()
    .sort_values('mean', ascending=False)
)

print(type_stats)

fig, ax = plt.subplots(figsize=(12, 6))

palette = ['#E63946', '#457B9D', '#2A9D8F', '#E9C46A', '#F4A261', '#A8DADC']

bars = ax.bar(
    type_stats['type'],
    type_stats['mean'],
    color=palette[:len(type_stats)],
    edgecolor='white',
    linewidth=1.2,
    width=0.6,
    yerr=type_stats['std'],
    capsize=5,
    error_kw=dict(elinewidth=1.2, ecolor='#555555')
)

# value labels on bars
for bar, (_, row) in zip(bars, type_stats.iterrows()):
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height() + 0.05,
        f"{row['mean']:.2f}\n(n={int(row['count']):,})",
        ha='center', va='bottom', fontsize=9, fontweight='bold'
    )

# mean reference line overall
overall_mean = df_scored['score'].mean()
ax.axhline(overall_mean, color='#333333', linestyle='--', linewidth=1.5, label=f'Overall mean: {overall_mean:.2f}')

ax.set_title('Average Score by Anime Type\n(error bars show standard deviation)',
             fontsize=16, fontweight='bold', pad=20)
ax.set_xlabel('Anime Type', fontsize=12)
ax.set_ylabel('Average Score', fontsize=12)
ax.set_ylim(0, 10)
ax.legend(fontsize=10)
ax.grid(axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.savefig(OUT_PATH + 'chart4_avg_score_by_type.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
#       type      mean  median  count       std
# 3  Special  6.400516   6.410   1492  0.729570
# 1      ONA  6.251472   6.205   2398  0.897250
# 2      OVA  6.233366   6.220   3500  0.804709
# 0    Music  5.947909   5.930   2343  0.670733

# %% [markdown]
# ## Does Format Affect Quality? Average Score by Anime Type
#
# This chart compares how users rate different anime formats, ranked from
# highest to lowest average score.
#
# **What the data tells us:**
# - **TV series score the highest (6.83)** — well above the overall mean of
#   6.39, despite being the largest group (n=5,122). This suggests that the
#   episodic format, which allows for deeper storytelling and character
#   development, is consistently rewarded by audiences
# - **Music anime score the lowest (5.95)** — the only type to fall below 6.0,
#   which makes sense as music videos and short promotional anime are rarely
#   rated for narrative quality
# - **Movies, ONA and OVA all cluster tightly around 6.23–6.36** — just below
#   the overall mean, suggesting these formats are more hit-or-miss
# - **Specials (6.40)** sit right at the overall mean — they neither
#   overperform nor underperform consistently
# - The **error bars on Movies are the widest** — meaning movie quality varies
#   more wildly than any other type, from masterpieces to forgettable releases
#
# **Conclusion:** Format is a surprisingly strong signal of quality.
# If you want a consistently good watch, TV series are statistically
# your safest bet.

# %%
# using Folium for interactive map
try:
    import folium
    from folium.plugins import HeatMap
except ImportError:
    print("Folium not installed. Run: pip install folium")

df = pd.read_csv(CLEAN_PATH + 'profiles_clean.csv')

# Drop rows with no location
df = df.dropna(subset=['location'])
df['location'] = df['location'].str.strip()

print(f"Total users with location: {len(df):,}")
## print(f"Sample locations:\n{df['location'].value_counts().head(20)}") not unnecessary but taking too much space


# =================================
# EXTRACTING COUNTRY FROM LOCATION
# =================================

# location field is basically free text (Tokyo, Japan, United States, Germany)
# we extract the last token after the last comma as the country

def extract_country(location):
    if pd.isna(location):
        return None
    parts = [p.strip() for p in str(location).split(',')]
    return parts[-1].strip()

df['country_raw'] = df['location'].apply(extract_country)

# Manual normalisation for common variants
country_map = {
    'USA'                       : 'United States',
    'US'                        : 'United States',
    'U.S.A.'                    : 'United States',
    'U.S.'                      : 'United States',
    'United States of America'  : 'United States',
    'UK'                        : 'United Kingdom',
    'U.K.'                      : 'United Kingdom',
    'England'                   : 'United Kingdom',
    'Scotland'                  : 'United Kingdom',
    'Wales'                     : 'United Kingdom',
    'Brasil'                    : 'Brazil',
    'Россия'                    : 'Russia',
    'Deutschland'               : 'Germany',
    'Polska'                    : 'Poland',
    'Nederland'                 : 'Netherlands',
    'Việt Nam'                  : 'Vietnam',
    'Türkiye'                   : 'Turkey',
    'México'                    : 'Mexico',
    'España'                    : 'Spain',
    'Italia'                    : 'Italy',
    'República Dominicana'      : 'Dominican Republic',
    'Schweiz'                   : 'Switzerland',
}

df['country'] = df['country_raw'].replace(country_map)

# number of users per country
country_counts = (
    df['country']
    .value_counts()
    .reset_index()
)
country_counts.columns = ['country', 'count']

## print(f"\nTop 20 countries:\n{country_counts.head(20)}") this one as well taking too much space


# (the great interactive Map using FOLIUM)

# country coordinates for mapping
country_coords = {
    'United States'   : [37.09,  -95.71],
    'Japan'           : [36.20,  138.25],
    'Brazil'          : [-14.24, -51.93],
    'Germany'         : [51.17,   10.45],
    'United Kingdom'  : [55.38,   -3.44],
    'Philippines'     : [12.88,  121.77],
    'France'          : [46.23,    2.21],
    'Canada'          : [56.13,  -106.35],
    'Indonesia'       : [-0.79,  113.92],
    'Australia'       : [-25.27,  133.78],
    'Mexico'          : [23.63,  -102.55],
    'Poland'          : [51.92,   19.15],
    'Russia'          : [61.52,  105.32],
    'Italy'           : [41.87,   12.57],
    'Spain'           : [40.46,   -3.75],
    'Argentina'       : [-38.42, -63.62],
    'Thailand'        : [15.87,  100.99],
    'Netherlands'     : [52.13,    5.29],
    'Turkey'          : [38.96,   35.24],
    'Vietnam'         : [14.06,  108.28],
    'Sweden'          : [60.13,   18.64],
    'Malaysia'        : [4.21,   101.98],
    'Romania'         : [45.94,   24.97],
    'India'           : [20.59,   78.96],
    'Chile'           : [-35.68, -71.54],
    'Portugal'        : [39.40,   -8.22],
    'Hungary'         : [47.16,   19.50],
    'Czech Republic'  : [49.82,   15.47],
    'Colombia'        : [4.57,   -74.30],
    'Finland'         : [61.92,   25.75],
    'Norway'          : [60.47,    8.47],
    'Denmark'         : [56.26,    9.50],
    'South Korea'     : [35.91,  127.77],
    'Taiwan'          : [23.70,  120.96],
    'Greece'          : [39.07,   21.82],
    'Belgium'         : [50.50,    4.47],
    'Switzerland'     : [46.82,    8.23],
    'Peru'            : [-9.19,  -75.02],
    'Venezuela'       : [6.42,   -66.59],
    'Ukraine'         : [48.38,   31.17],
    'Saudi Arabia'    : [23.89,   45.08],
}

# merging counts with coordinates
country_counts['coords'] = country_counts['country'].map(country_coords)
df_map = country_counts.dropna(subset=['coords'])

# now we build folium map
m = folium.Map(location=[20, 0], zoom_start=2,
               tiles='CartoDB positron')

# ideally we use circle markers scaled by user count
max_count = df_map['count'].max()

for _, row in df_map.iterrows():
    lat, lon = row['coords']
    count    = row['count']
    radius   = 5 + (count / max_count) * 35

    folium.CircleMarker(
        location=[lat, lon],
        radius=radius,
        color='#E63946',
        fill=True,
        fill_color='#E63946',
        fill_opacity=0.6,
        tooltip=f"<b>{row['country']}</b><br>Users: {count:,}"
    ).add_to(m)

title_html = '''
<div style="position: fixed; top: 15px; left: 50%; transform: translateX(-50%);
     z-index: 1000; background-color: white; padding: 10px 20px;
     border-radius: 8px; box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
     font-family: Arial; font-size: 16px; font-weight: bold;">
     🌍 Global Distribution of Anime Fans
</div>
'''
m.get_root().html.add_child(folium.Element(title_html))

m.save(OUT_PATH + 'chart5_world_map.html') # used to make it visible on github
m # the map automatically renders inside the jupyter notebook
# Out:
# Total users with location: 337,154
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## Global Distribution of Anime Fans
#
# This interactive map visualises where MyAnimeList users are located
# across the world. Each circle represents a country — the larger the
# circle, the more anime fans are based there.
#
# **What the map tells us:**
# - **The United States dominates** — by far the largest circle on the map,
#   reflecting the massive Western fanbase that anime has built since
#   the early 2000s
# - **Brazil stands out in South America** — easily the largest anime
#   community in Latin America, making it one of the top countries
#   globally for anime viewership
# - **Europe shows a wide spread** — Germany, France, Poland and the UK
#   all have notable communities, suggesting anime has strong penetration
#   across the entire continent rather than being concentrated in one country
# - **Southeast Asia is well represented** — the Philippines, Indonesia,
#   Vietnam and Malaysia all appear prominently, reflecting the cultural
#   proximity to Japanese media
# - **Japan itself has a surprisingly modest circle** — this is likely
#   because Japanese fans use domestic platforms rather than
#   MyAnimeList, which is primarily an English-language platform
#
# **How to use the map:**
# Hover over any circle to see the exact country name and user count.
# Scroll to zoom in and out.
#
# **Conclusion:** Anime is a truly global phenomenon — while it originated
# in Japan, its largest and most active online fanbase is spread across
# North America, South America and Europe.

# %%
top20 = country_counts.head(20).sort_values('count', ascending=True)

fig, ax = plt.subplots(figsize=(12, 9))

bars = ax.barh(
    top20['country'],
    top20['count'],
    color='#457B9D',
    edgecolor='white',
    linewidth=0.8
)

# value labels
for bar, count in zip(bars, top20['count']):
    ax.text(
        bar.get_width() + top20['count'].max() * 0.005,
        bar.get_y() + bar.get_height() / 2,
        f'{count:,}',
        va='center', ha='left', fontsize=9
    )

# top country needs to be highlighted
bars[-1].set_color('#E63946')

ax.set_title('Top 20 Countries by Number of Anime Fans\n(based on MyAnimeList user profiles)',
             fontsize=15, fontweight='bold', pad=20)
ax.set_xlabel('Number of Users', fontsize=12)
ax.set_ylabel('')
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{int(x):,}'))
ax.grid(axis='x', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.savefig(OUT_PATH + 'chart6_top20_countries.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Top 20 Countries by Number of Anime Fans
#
# This chart ranks the top 20 countries by the number of MyAnimeList
# users who listed them as their location.
#
# **What the data tells us:**
# - **Japan leads with 98,316 users** — contrary to what the interactive
#   map suggested, Japan is actually the most represented country in
#   this dataset. This makes sense as MyAnimeList was originally built
#   for and by Japanese fans, and has a very active domestic user base
# - **The United States comes second with 65,240 users** — nearly 33,000
#   fewer than Japan, but still far ahead of every other country,
#   confirming the massive Western fanbase anime has accumulated
# - **Germany (26,348) and the United Kingdom (19,520) lead Europe** —
#   both significantly ahead of France (10,041) and Spain (12,916),
#   suggesting Northern and Central Europe have stronger anime
#   communities than the South
# - **Thailand (16,416) is the highest ranked Southeast Asian country** —
#   ahead of Indonesia, Vietnam and the Philippines, reflecting
#   Thailand's particularly strong anime culture in the region
# - **Argentina (13,230) outranks China (13,196)** — notable given
#   China's population of 1.4 billion versus Argentina's 45 million,
#   suggesting Chinese fans prefer domestic platforms over MyAnimeList
# - **Egypt (3,239) is the only African country** in the top 20 —
#   hinting at an emerging but still underrepresented anime audience
#   across the African continent
#
# **Conclusion:** Anime fandom is dominated by Japan and the United
# States but is genuinely global — with strong communities across
# Europe, Latin America, Southeast Asia and beyond.

# %%
stats   = pd.read_csv(CLEAN_PATH + 'stats_clean.csv')
details = pd.read_csv(CLEAN_PATH + 'details_clean.csv')

# Merge to get anime titles
df = stats.merge(details[['mal_id', 'title', 'type', 'score']], on='mal_id', how='left')

# drop rate = dropped / total (only consider anime with enough engagement)
# we us a minimum 1000 total interactions to filter out obscure titles
df_engaged = df[df['total'] >= 1000].copy()
df_engaged['drop_rate'] = (df_engaged['dropped'] / df_engaged['total'] * 100).round(2)

# Top 20 highest drop rates
top_dropped = df_engaged.nlargest(50, 'drop_rate').sort_values('drop_rate', ascending=True)

print(f"\nTop 10 most dropped anime:")
print(top_dropped[['title', 'drop_rate', 'total', 'score']].tail(10))

# here we start plotting
fig, ax = plt.subplots(figsize=(13, 9))

# colour bars are based on drop rate intensity
colors = ['#E63946' if r >= 25 else '#F4A261' if r >= 20 else '#457B9D'
          for r in top_dropped['drop_rate']]

bars = ax.barh(
    top_dropped['title'],
    top_dropped['drop_rate'],
    color=colors,
    edgecolor='white',
    linewidth=0.8
)

# value labels
for bar, rate in zip(bars, top_dropped['drop_rate']):
    ax.text(
        bar.get_width() + 0.2,
        bar.get_y() + bar.get_height() / 2,
        f'{rate:.1f}%',
        va='center', ha='left', fontsize=9
    )

# using a legend for colour coding
from matplotlib.patches import Patch
legend_elements = [
    Patch(facecolor='#E63946', label='Drop rate ≥ 30%'),
    Patch(facecolor='#F4A261', label='Drop rate 20–25%'),
    Patch(facecolor='#457B9D', label='Drop rate < 20%'),
]
ax.legend(handles=legend_elements, fontsize=9, loc='lower right')

ax.set_title('Top 20 Anime by Drop Rate\n(minimum 1,000 user interactions)',
             fontsize=15, fontweight='bold', pad=20)
ax.set_xlabel('Drop Rate (%)', fontsize=12)
ax.set_ylabel('')
ax.grid(axis='x', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.savefig(OUT_PATH + 'chart7_highest_drop_rate.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# Top 10 most dropped anime:
#                              title  drop_rate  total  score
# 26914   Xi Yangyang Yu Hui Tailang      26.66   1039   6.36
# 24079                   Tasuuketsu      26.67  25017   5.55
# 17776                    Ojarumaru      27.03   2390   6.37
# 8280                     Hanakappa      27.19   1140   5.94
# 7256                       Gibiate      27.32  70782   3.82
# 24566               The Reflection      27.69  30273   5.12
# 18747  Peeping Life TV: Season 1??      27.91   2845   5.67
# 3456   Charady no Joke na Mainichi      30.23   2805   5.13
# 14933               Manul no Yuube      30.29   1053    NaN
# 6062                        Ex-Arm      38.06  85476   2.88

# %% [markdown]
# **In this graph we can see the drop rate of the animes. I was able to see even the under 20% rate animes but the chart was looking incomprehensible. I tried to increase the number from 50 to 100 and it was not possible to understand it completely.**
#
# In this next part, i wanted to see how the stats and details might correlate to the amount of favourite drops. The question would be "Are these details and stats directly correlated to fewer favourites of said animes?".
#
# **Let's take a look at it**

# %%
from scipy import stats


stats_df   = pd.read_csv(CLEAN_PATH + 'stats_clean.csv')
details_df = pd.read_csv(CLEAN_PATH + 'details_clean.csv')
favs_df    = pd.read_csv(CLEAN_PATH + 'favs_clean.csv')

# decided to count how many times each anime was recommended
rec_counts = (
    favs_df[favs_df['fav_type'] == 'anime']
    .groupby('id')
    .size()
    .reset_index(name='rec_count')
    .rename(columns={'id': 'mal_id'})
)

#drop rate from stats
stats_df = stats_df[stats_df['total'] >= 1000].copy()
stats_df['drop_rate'] = (stats_df['dropped'] / stats_df['total'] * 100).round(2)

# merging everything together
df = stats_df.merge(details_df[['mal_id', 'title', 'type', 'score']], on='mal_id', how='left')
df = df.merge(rec_counts, on='mal_id', how='left')
df['rec_count'] = df['rec_count'].fillna(0)

# dropping rows with missing values
df = df.dropna(subset=['drop_rate', 'rec_count', 'score'])

print(f"Total anime in analysis: {len(df):,}")
print(df[['title', 'drop_rate', 'rec_count', 'score']].sort_values('drop_rate', ascending=False).head(10))


# Since the Spearman correlation implies the question "how well the relationship can be described?"
# i supposed this was the best way to look at the chart

spearman_r, p_value = stats.spearmanr(df['drop_rate'], df['rec_count'])

print(f"\nSpearman r  : {spearman_r:.4f}")
print(f"p-value     : {p_value:.4e}")
print(f"Significant : {'Yes' if p_value < 0.05 else 'No'} (α=0.05)")


# here's a look at the chart

print("\nBuilding chart: Drop Rate vs Recommendation Count...")

fig, ax = plt.subplots(figsize=(14, 8))

# log scale on y-axis for rec_count
# and colour points by anime type
type_colors = {
    'TV'      : '#E63946',
    'Movie'   : '#457B9D',
    'OVA'     : '#2A9D8F',
    'ONA'     : '#E9C46A',
    'Special' : '#F4A261',
}

for anime_type, color in type_colors.items():
    mask = df['type'] == anime_type
    ax.scatter(
        df.loc[mask, 'drop_rate'],
        df.loc[mask, 'rec_count'] + 1,  # +1 to avoid log(0)
        color=color,
        alpha=0.4,
        s=20,
        label=anime_type,
        edgecolors='none'
    )

# using a trend line on log-transformed rec_count
x = df['drop_rate']
y = np.log10(df['rec_count'] + 1)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
x_line = np.linspace(x.min(), x.max(), 300)
ax.plot(x_line, 10 ** p(x_line), color='#333333',
        linewidth=2, linestyle='--', label='Trend line', zorder=5)

# annotations to show top recommended anime
top_rec = df.nlargest(5, 'rec_count')
for _, row in top_rec.iterrows():
    ax.annotate(
        row['title'],
        xy=(row['drop_rate'], row['rec_count'] + 1),
        xytext=(8, 4), textcoords='offset points',
        fontsize=7, color='#333333',
        arrowprops=dict(arrowstyle='->', color='gray', lw=0.8)
    )

# and then the most dropped anime
top_drop = df.nlargest(3, 'drop_rate')
for _, row in top_drop.iterrows():
    ax.annotate(
        row['title'],
        xy=(row['drop_rate'], row['rec_count'] + 1),
        xytext=(8, 4), textcoords='offset points',
        fontsize=7, color='#E63946',
        arrowprops=dict(arrowstyle='->', color='#E63946', lw=0.8)
    )

# Spearman annotation box
significance = "p < 0.001 ✓" if p_value < 0.001 else f"p = {p_value:.3f}"
ax.text(0.97, 0.97,
        f'Spearman r = {spearman_r:.3f}\n{significance}',
        transform=ax.transAxes,
        fontsize=11, va='top', ha='right',
        bbox=dict(boxstyle='round', facecolor='white', alpha=0.8, edgecolor='#cccccc'))

ax.set_yscale('log')
ax.set_title('Do Dropped Anime Get Favourited Less?\nDrop Rate vs Favourite Count by Anime Type',
             fontsize=15, fontweight='bold', pad=20)
ax.set_xlabel('Drop Rate (%)', fontsize=12)
ax.set_ylabel('Number of favorites (log scale)', fontsize=12)
ax.legend(title='Anime Type', fontsize=9, loc='upper right',
          bbox_to_anchor=(0.85, 0.97))
ax.grid(linestyle='--', alpha=0.3)
plt.tight_layout()
plt.savefig(OUT_PATH + 'chart7b_droprate_vs_rfavs.png', dpi=150, bbox_inches='tight')
plt.show()
print("  Saved → chart7b_droprate_vs_favs.png")
# Out:
# Total anime in analysis: 14,270
#                                                 title  drop_rate  rec_count  \
# 3271                                           Ex-Arm      38.06       34.0
# 1859                      Charady no Joke na Mainichi      30.23        0.0
# 9914                      Peeping Life TV: Season 1??      27.91        0.0
# 12868                                  The Reflection      27.69        0.0
# 3931                                          Gibiate      27.32        3.0
# 4518                                        Hanakappa      27.19        0.0
# 9385                                        Ojarumaru      27.03        0.0
# 12565                                      Tasuuketsu      26.67        5.0
# 14052                      Xi Yangyang Yu Hui Tailang      26.66        1.0
# 2023   Choujigen Kakumei Anime: Dimension High School      26.47        4.0
#
#        score
# 3271    2.88
# 1859    5.13
# 9914    5.67
# 12868   5.12
# 3931    3.82
# ...

# %% [markdown]
# ## Do Dropped Anime Get Favourited Less?
#
# This chart analyses whether anime that audiences abandon also tend
# to receive fewer favourites — combining drop rate data from stats with
# favourite counts from user profiles across 3 datasets.
#
# Each dot represents one anime, coloured by type. The x-axis shows the
# drop rate (% of users who added it to their list but gave up), while
# the y-axis shows how many times it was favourited (log scale).
#
# **What the Spearman correlation tells us:**
# - **Spearman r = -0.188, p < 0.001** — there is a **statistically
#   significant negative correlation**, meaning that anime with higher drop
#   rates do tend to get fewer favourites
# - However, r = -0.188 is a **weak correlation** — drop rate alone
#   explains only a small part of why an anime gets favourited or not
# - The result is significant not because the effect is large, but
#   because the dataset is large — with thousands of anime, even
#   small patterns become statistically detectable
#
# **What the chart visually shows:**
# - The **dense cluster at the left** (drop rate 0–5%) contains almost
#   all the highly favourited anime — Hunter x Hunter, Fullmetal
#   Alchemist: Brotherhood, Shingeki no Kyojin and One Piece all sit
#   here with tens of thousands of favourites
# - As drop rate increases, the cloud of points **drops massively** —
#   very few anime with a 20%+ drop rate accumulate meaningful favourites
# - **Ex-Arm is a notable outlier** — it has one of the highest drop
#   rates (~38%) yet still has a small but visible favourite count,
#   suggesting it became something of an ironic cult favourite
# - **TV series (red dots) dominate the high-favourite zone** —
#   consistent with our earlier finding that TV series score higher
#   and retain audiences better than other formats
#
# **Conclusion:** The data confirms the intuition — audiences that
# abandon an anime rarely go on to favourite it. But the weak
# correlation also tells an interesting story: a low drop rate is
# necessary but not sufficient for an anime to become beloved.
# Plenty of anime are rarely dropped yet never favourited either.

# %%
details_df = pd.read_csv(CLEAN_PATH + 'details_clean.csv')
stats_df   = pd.read_csv(CLEAN_PATH + 'stats_clean.csv')
profiles   = pd.read_csv(CLEAN_PATH + 'profiles_clean.csv')
recs_df    = pd.read_csv(CLEAN_PATH + 'recommendations_clean.csv')

#Overall score distribution

print("Building Chart A: Score distribution...")

df_scored = details_df.dropna(subset=['score'])

fig, ax = plt.subplots(figsize=(14, 6))

n, bins, patches = ax.hist(
    df_scored['score'],
    bins=40,
    color='#457B9D',
    edgecolor='white',
    linewidth=0.6
)

# Highlight the 6–8 range in a different colour
for patch, left in zip(patches, bins[:-1]):
    if 6.0 <= left <= 8.0:
        patch.set_facecolor('#E63946')

# Mean and median lines
mean_score   = df_scored['score'].mean()
median_score = df_scored['score'].median()

ax.axvline(mean_score,   color='#2A9D8F', linewidth=2,
           linestyle='--', label=f'Mean: {mean_score:.2f}')
ax.axvline(median_score, color='#E9C46A', linewidth=2,
           linestyle='--', label=f'Median: {median_score:.2f}')

# Annotation for bias zone
ax.axvspan(6, 8, alpha=0.08, color='#E63946', label='6–8 bias zone')
pct_in_zone = ((df_scored['score'] >= 6) & (df_scored['score'] <= 8)).mean() * 100
ax.text(6.9, n.max() * 0.92,
        f'{pct_in_zone:.1f}% of all\nscored anime\nfall here',
        ha='center', fontsize=10, color='#E63946', fontweight='bold')

ax.set_title('Is There a Rating Bias Towards 6–8?\nOverall Score Distribution Across All Anime',
             fontsize=15, fontweight='bold', pad=20)
ax.set_xlabel('Score', fontsize=12)
ax.set_ylabel('Number of Anime', fontsize=12)
ax.legend(fontsize=10)
ax.grid(axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.savefig(OUT_PATH + 'chartA_score_distribution.png', dpi=150, bbox_inches='tight')
plt.show()
print("  Saved → chartA_score_distribution.png")
# Out:
# Building Chart A: Score distribution...
#   Saved → chartA_score_distribution.png

# %% [markdown]
# ## Is There a Rating Bias Towards 6–8?
#
# This histogram shows how scores are distributed across all scored
# anime in the dataset. Each bar represents a score range, and the
# red zone highlights the 6–8 range that we suspected might
# attract a disproportionate share of ratings.
#
# **What the data tells us:**
# - **62.4% of all scored anime fall between 6 and 8** — confirming
#   there is a very strong concentration of scores in this range
# - The distribution is **roughly bell-shaped but right-skewed** —
#   the peak sits around 6.5–7.0, and the tail extends further
#   towards 9–10 than towards 1–2
# - **Mean (6.39) and median (6.36) are nearly identical** — sitting
#   almost perfectly on top of each other, which tells us the
#   distribution is quite symmetric around its centre despite the skew
# - **Scores below 4 are extremely rare** — very few anime score
#   that poorly, suggesting either that truly bad anime don't
#   accumulate enough votes to register, or that users tend to
#   avoid rating anime they disliked
# - **Scores of 9 and above are also rare** — achieving a score
#   above 9 is genuinely exceptional, with only a handful of
#   anime reaching that level
#
# **Why does the 6–8 bias exist?**
# Several factors likely contribute:
# - Users tend to complete anime they enjoy and rate those,
#   creating a positive selection bias
# - A score of 6 or 7 is the natural "it was fine" rating —
#   most anime are consumed, enjoyed adequately, and rated
#   in this middle zone
# - Truly exceptional or truly terrible anime are rare by
#   definition, so the extremes naturally have fewer entries
#
# **Conclusion:** The 6–8 bias is real and strong — nearly two
# thirds of all anime cluster in this narrow range. This means
# differences within this zone are less meaningful, and anime
# that break out above 8.0 or below 5.0 are genuinely
# statistical outliers worth paying attention to.

# %%
status_totals = pd.Series({
    'Completed'    : profiles['completed'].sum(),
    'Plan to Watch': profiles['plan_to_watch'].sum(),
    'Watching'     : profiles['watching'].sum(),
    'Dropped'      : profiles['dropped'].sum(),
    'On Hold'      : profiles['on_hold'].sum(),
}).sort_values(ascending=False)

total_entries = status_totals.sum()
status_pct    = (status_totals / total_entries * 100).round(2)

colors = ['#2A9D8F', '#457B9D', '#E9C46A', '#E63946', '#F4A261']

fig, axes = plt.subplots(1, 2, figsize=(16, 7))
fig.suptitle('How Do Users Engage With Anime?\nWatchlist Status Distribution',
             fontsize=15, fontweight='bold', y=1.02)

# Left: bar chart
bars = axes[0].bar(
    status_totals.index,
    status_totals.values,
    color=colors,
    edgecolor='white',
    linewidth=1.2,
    width=0.6
)
for bar, pct in zip(bars, status_pct.values):
    axes[0].text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height() + total_entries * 0.003,
        f'{pct:.1f}%',
        ha='center', va='bottom', fontsize=10, fontweight='bold'
    )
axes[0].set_title('Total Entries by Status', fontsize=12, fontweight='bold')
axes[0].set_ylabel('Number of Entries', fontsize=11)
axes[0].yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{int(x):,}'))
axes[0].grid(axis='y', linestyle='--', alpha=0.4)
axes[0].tick_params(axis='x', rotation=15)

# Right: pie chart
wedges, texts, autotexts = axes[1].pie(
    status_totals.values,
    labels=status_totals.index,
    colors=colors,
    autopct='%1.1f%%',
    startangle=140,
    pctdistance=0.82,
    wedgeprops=dict(edgecolor='white', linewidth=1.5)
)
for text in texts:
    text.set_fontsize(11)
for autotext in autotexts:
    autotext.set_fontsize(9)
    autotext.set_fontweight('bold')
axes[1].set_title('Proportional Breakdown', fontsize=12, fontweight='bold')

plt.tight_layout()
plt.savefig(OUT_PATH + 'chartB_watchlist_status.png', dpi=150, bbox_inches='tight')
plt.show()
print("  Saved → chartB_watchlist_status.png")
# Out:
#   Saved → chartB_watchlist_status.png

# %% [markdown]
# ## How Do Users Engage With Anime?
#
# This chart combines a bar chart and pie chart to show how over
# 100 million watchlist entries are distributed across the five
# possible statuses on MyAnimeList.
#
# **What the data tells us:**
# - **Completed dominates at 60.8%** — the majority of anime on
#   users' lists have been fully watched, suggesting that
#   MyAnimeList users are largely committed viewers who follow
#   through on what they start
# - **Plan to Watch is second at 26.6%** — over a quarter of all
#   entries are anime users intend to watch but haven't started
#   yet, reflecting the phenomenon of endlessly growing watchlists
#   that many fans will recognise
# - **Watching accounts for only 5.1%** — at any given moment,
#   users are actively watching a relatively small slice of their
#   total list, which makes sense given how many anime are seasonal
# - **Dropped is 4.3%** — despite the large total dataset, less
#   than 1 in 20 entries ends in abandonment, suggesting users
#   are fairly selective about what they add to their lists in
#   the first place
# - **On Hold is the smallest at 3.3%** — the "I'll get back to
#   it someday" category, which in practice often becomes a
#   permanent resting place for anime that were neither good
#   enough to finish nor bad enough to officially drop
#
# **Completed + Plan to Watch = 87.4% of all entries** —
# meaning the overwhelming majority of user engagement is
# either finishing anime or intending to. This paints a
# picture of a highly motivated and engaged fanbase.
#
# **Conclusion:** MyAnimeList users are finishers — the data
# strongly suggests that once an anime makes it onto a user's
# list, it is far more likely to be completed than abandoned.
# The real bottleneck is not completion but the ever-growing
# backlog of anime users plan to eventually watch.

# %%
rec_counts = (
    recs_df.groupby('recommendation_mal_id')
    .size()
    .reset_index(name='rec_count')
    .rename(columns={'recommendation_mal_id': 'mal_id'})
)

# Merge with details to get titles and scores
rec_counts = rec_counts.merge(
    details_df[['mal_id', 'title', 'score', 'type']],
    on='mal_id', how='left'
)

top20_rec = rec_counts.nlargest(50, 'rec_count').sort_values('rec_count', ascending=True)

fig, ax = plt.subplots(figsize=(13, 9))

# Colour by type
type_colors = {
    'TV'     : '#E63946',
    'Movie'  : '#457B9D',
    'OVA'    : '#2A9D8F',
    'ONA'    : '#E9C46A',
    'Special': '#F4A261',
}
bar_colors = [type_colors.get(t, '#AAAAAA') for t in top20_rec['type']]

bars = ax.barh(
    top20_rec['title'],
    top20_rec['rec_count'],
    color=bar_colors,
    edgecolor='white',
    linewidth=0.8
)

# Value labels with score
for bar, (_, row) in zip(bars, top20_rec.iterrows()):
    ax.text(
        bar.get_width() + 5,
        bar.get_y() + bar.get_height() / 2,
        f"{int(row['rec_count']):,}  (score: {row['score']:.2f})",
        va='center', ha='left', fontsize=8.5
    )

# Legend for type colours
from matplotlib.patches import Patch
legend_elements = [Patch(facecolor=c, label=t) for t, c in type_colors.items()]
ax.legend(handles=legend_elements, title='Type', fontsize=9, loc='lower right')

ax.set_title('Top 20 Most Recommended Anime\n(with average score)',
             fontsize=15, fontweight='bold', pad=20)
ax.set_xlabel('Number of Recommendations', fontsize=12)
ax.grid(axis='x', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.savefig(OUT_PATH + 'chartC_top20_recommended.png', dpi=150, bbox_inches='tight')
plt.show()
print("  Saved → chartC_top20_recommended.png")
# Out:
#   Saved → chartC_top20_recommended.png

# %% [markdown]
# ## Top 20 Most Recommended Anime
#
# This chart shows which anime appear most frequently in user
# recommendations across the entire dataset, with each bar
# also displaying the anime's average score. Bars are coloured
# by format type.
#
# **What the data tells us:**
# - **Shinseiki Evangelion leads with 300 recommendations** —
#   making it the single most recommended anime in the entire
#   dataset, despite having a score of 8.36 which is high but
#   not the highest on this list. Its cultural influence
#   clearly transcends its raw score
# - **TV series completely dominate the list** — almost every
#   bar is red, with only FLCL (OVA) and a couple of others
#   breaking the pattern. This reinforces our earlier finding
#   that TV series are the most engaging and memorable format
# - **High scores don't guarantee high recommendations** —
#   Steins;Gate (9.07) and Fullmetal Alchemist: Brotherhood
#   (9.10) are among the highest rated anime ever, yet they
#   sit mid-table in recommendations. Meanwhile Sword Art
#   Online (7.22) and Elfen Lied (7.46) rank higher despite
#   more modest scores
# - **Guilty Crown and Mirai Nikki appear despite lower scores**
#   (7.40 and 7.38 respectively) — suggesting these anime are
#   recommended not because they are universally loved, but
#   because they spark strong reactions and conversations
# - **The recommendation gap is large** — Evangelion at 300
#   is nearly double the anime at the bottom of the top 20,
#   showing that recommendation power is heavily concentrated
#   in a small group of iconic titles
# - **Most recommended anime cluster around score 8.0–8.5** —
#   suggesting that the sweet spot for getting recommended
#   is being very good but not necessarily perfect
#
# **Conclusion:** Recommendations are driven by cultural
# impact and conversation value as much as by raw quality.
# The most recommended anime are not always the highest
# scored — they are the ones that left the biggest
# impression and made viewers want to share the experience.

# %%
df_d = details_df.dropna(subset=['score']).merge(rec_counts[['mal_id','rec_count']], on='mal_id', how='left')
df_d['rec_count'] = df_d['rec_count'].fillna(0)

spearman_r, p_value = stats.spearmanr(df_d['score'], df_d['rec_count'])
print(f"  Spearman r = {spearman_r:.4f} | p = {p_value:.4e}")

fig, ax = plt.subplots(figsize=(14, 7))

type_colors = {
    'TV'     : '#E63946',
    'Movie'  : '#457B9D',
    'OVA'    : '#2A9D8F',
    'ONA'    : '#E9C46A',
    'Special': '#F4A261',
}

for anime_type, color in type_colors.items():
    mask = df_d['type'] == anime_type
    ax.scatter(
        df_d.loc[mask, 'score'],
        df_d.loc[mask, 'rec_count'] + 1,
        color=color, alpha=0.35, s=18,
        label=anime_type, edgecolors='none'
    )

# Trend line
x = df_d['score']
y = np.log10(df_d['rec_count'] + 1)
z = np.polyfit(x, y, 1)
p_fit = np.poly1d(z)
x_line = np.linspace(x.min(), x.max(), 300)
ax.plot(x_line, 10 ** p_fit(x_line), color='#333333',
        linewidth=2, linestyle='--', label='Trend line', zorder=5)

# Annotate top 5 most recommended
top5 = df_d.nlargest(5, 'rec_count')
for _, row in top5.iterrows():
    ax.annotate(
        row['title'],
        xy=(row['score'], row['rec_count'] + 1),
        xytext=(8, 4), textcoords='offset points',
        fontsize=7.5, color='#333333',
        arrowprops=dict(arrowstyle='->', color='gray', lw=0.8)
    )

significance = "p < 0.001 ✓" if p_value < 0.001 else f"p = {p_value:.3f}"
ax.text(0.15, 0.97,
        f'Spearman r = {spearman_r:.3f}\n{significance}',
        transform=ax.transAxes,
        fontsize=11, va='top', ha='left',
        bbox=dict(boxstyle='round', facecolor='white', alpha=0.8, edgecolor='#cccccc'))

ax.set_yscale('log')
ax.set_title('Do Highly Rated Anime Get Recommended More?\nScore vs Recommendation Count',
             fontsize=15, fontweight='bold', pad=20)
ax.set_xlabel('Score', fontsize=12)
ax.set_ylabel('Number of Recommendations (log scale)', fontsize=12)
ax.legend(title='Type', fontsize=9)
ax.grid(linestyle='--', alpha=0.3)
plt.tight_layout()
plt.savefig(OUT_PATH + 'chartD_score_vs_recommendations.png', dpi=150, bbox_inches='tight')
plt.show()
print("  Saved → chartD_score_vs_recommendations.png")
# Out:
#   Spearman r = 0.3774 | p = 0.0000e+00
#   Saved → chartD_score_vs_recommendations.png

# %% [markdown]
# ## Do Highly Rated Anime Get Recommended More?
#
# This scatter plot explores whether the quality of an anime —
# measured by its score — drives how often it gets recommended
# by other users. Each dot is one anime, coloured by type, with
# a log scale on the y-axis to handle the heavily skewed
# recommendation counts.
#
# **What the Spearman correlation tells us:**
# - **Spearman r = 0.377, p < 0.001** — there is a statistically
#   significant moderate positive correlation between score and
#   recommendation count
# - This is stronger than the drop rate correlation (r = -0.188)
#   we found earlier — meaning score is a better predictor of
#   being recommended than drop rate is
# - However r = 0.377 still leaves a lot unexplained — many
#   highly scored anime receive very few recommendations, and
#   a few lower-scored anime receive many
#
# **What the chart visually shows:**
# - **The horizontal bands at y = 1, 2, 3** are anime with very
#   few recommendations — they form flat lines because most
#   anime receive 0–3 recommendations regardless of score
# - **The cloud explodes upward above score 7.0** — once an
#   anime crosses this threshold, the range of recommendation
#   counts widens dramatically, with some reaching 100–300
# - **The top right cluster** contains the most recommended
#   anime — Shinseiki Evangelion, Mahou Shoujo Madoka Magica,
#   Code Geass and Tengen Toppa Gurren Lagann all sit here,
#   combining high scores with massive recommendation counts
# - **TV series (red dots) dominate the high recommendation
#   zone** — consistent with every previous finding that TV
#   is the most impactful format
# - **The trend line rises steeply** from score 2 to 9 —
#   visually confirming the positive relationship even
#   accounting for the log scale
#
# **Conclusion:** Score and recommendations are meaningfully
# correlated — a highly rated anime is significantly more
# likely to be recommended than a poorly rated one. But the
# relationship is not deterministic — cultural relevance,
# timing, and genre all play additional roles in what gets
# recommended, as Evangelion's dominance at the top clearly
# demonstrates.

# %%
# Hidden gem = high score but low number of votes (scored_by)
# Thresholds: score >= 8.0, scored_by <= 1000, scored_by >= 100
df_gems = details_df.dropna(subset=['score', 'scored_by'])
df_gems = df_gems[
    (df_gems['score'] >= 8.0) &
    (df_gems['scored_by'] <= 1000) &
    (df_gems['scored_by'] >= 100)
].copy()

df_gems = df_gems.sort_values('score', ascending=False).head(25)
df_gems = df_gems.sort_values('score', ascending=True)

print(f"\n  Hidden gems found: {len(df_gems)}")
print(df_gems[['title', 'score', 'scored_by', 'type']].tail(10))

fig, ax = plt.subplots(figsize=(13, 10))

scatter = ax.scatter(
    df_gems['scored_by'],
    df_gems['score'],
    c=df_gems['score'],
    cmap='RdYlGn',
    s=120,
    edgecolors='white',
    linewidth=0.8,
    zorder=3
)

# Annotate each gem
for _, row in df_gems.iterrows():
    ax.annotate(
        row['title'],
        xy=(row['scored_by'], row['score']),
        xytext=(3, 5), textcoords='offset points',
        fontsize=7.5, color='#333333'
    )

plt.colorbar(scatter, ax=ax, label='Score')

ax.set_title('Hidden Gems — Highly Rated But Barely Discovered\n(score ≥ 8.0, between 100–1,000 votes)',
             fontsize=15, fontweight='bold', pad=20)
ax.set_xlabel('Number of Votes (scored_by)', fontsize=12)
ax.set_ylabel('Score', fontsize=12)
ax.grid(linestyle='--', alpha=0.4)
plt.tight_layout()
plt.savefig(OUT_PATH + 'chartE_hidden_gems.png', dpi=150, bbox_inches='tight')
plt.show()
print("  Saved → chartE_hidden_gems.png")
# Out:
#   Hidden gems found: 3
#                                        title  score  scored_by type
# 3159                 Cang Yuan Tu 2nd Season   8.13      682.0  ONA
# 27840           Yi Nian Yong Heng 3rd Season   8.19      963.0  ONA
# 6137   Fanren Xiu Xian Chuan: Waihai Fengyun   8.24      542.0  ONA
#   Saved → chartE_hidden_gems.png

# %% [markdown]
# ## Hidden Gems — Highly Rated But Barely Discovered
#
# This chart surfaces anime that have achieved a score of 8.0 or
# above despite having been rated by only 100–1,000 users. These
# are titles that flew completely under the radar of the mainstream
# MAL community yet earned exceptional praise from the few who
# found them.
#
# **What the data tells us:**
# - **Only 3 anime meet the criteria** — score ≥ 8.0 with fewer
#   than 1,000 votes. This itself is a striking finding: it is
#   genuinely rare for an anime to maintain such a high score
#   with so little exposure. The 6–8 bias we identified earlier
#   means that most low-vote anime regress towards the mean
# - **Fanren Xiu Xian Chuan: Waihai Fengyun leads at 8.24**
#   with only ~550 votes — the highest score of the three and
#   the fewest votes, making it the most hidden gem in the
#   entire dataset
# - **Yi Nian Yong Heng 3rd Season scores 8.19** with just
#   under 1,000 votes — notably a sequel season, suggesting
#   that later seasons of niche series retain only the most
#   dedicated fans, who then rate them very highly
# - **Cang Yuan Tu 2nd Season scores 8.13** with ~690 votes —
#   again a sequel, reinforcing the pattern that continuation
#   seasons of obscure shows concentrate a loyal and
#   appreciative audience
# - **All three are Chinese donghua productions** — not
#   Japanese anime in the traditional sense, which likely
#   explains their low visibility on a platform historically
#   dominated by Japanese content
#
# **Conclusion:** True hidden gems are extremely rare — the
# combination of high quality and low discovery is almost
# self-correcting, since good anime tend to get recommended
# and discovered over time. The few that remain hidden are
# mostly niche sequel seasons or non-Japanese productions
# that sit outside the main discovery channels of the
# MAL community.
